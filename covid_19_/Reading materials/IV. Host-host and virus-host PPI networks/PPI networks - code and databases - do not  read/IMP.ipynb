# %%
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd

G = nx.read_graphml('IID.graphml')
nx.draw(G)
plt.show()

# %%
nodes_G=G.nodes()
print(nodes_G)
print(type(nodes_G))
# Out:
# ['MED19', 'POLR2D', 'POLR2B', 'POLR2C', 'POLR2E', 'POLR2F', 'POLR2G', 'POLR2H', 'POLR2I', 'POLR2L', 'RADIL', 'NFKBIA', 'DCK', 'ZC3H13', 'APP', 'FBXW7', 'POLR2K', 'ELL2', 'AFF4', 'MSX1', 'RPAP2', 'HECTD1', 'HERC2', 'NR2C2', 'DTX2', 'NEDD9', 'OSTF1', 'HLCS', 'GRB2', 'KANK2', 'SMAD1', 'SMAD2', 'UBR5', 'CHMP4B', 'BRD4', 'CHD9', 'SRSF3', 'CDC23', 'ZCCHC10', 'UBTF', 'ANAPC2', 'ZNF281', 'HCFC1', 'NOLC1', 'FBL', 'TCOF1', 'RUVBL1', 'RANGAP1', 'PPIG', 'NOL8', 'PNN', 'LMNA', 'AHCTF1', 'SMC4', 'ANAPC5', 'IPO4', 'RNPS1', 'PRPF4B', 'DDX21', 'DDB1', 'NUMA1', 'KPNA2', 'HSPD1', 'HSPA9', 'MYBBP1A', 'DNM2', 'DNAJA1', 'ZBTB9', 'LUC7L3', 'DDX20', 'CMSS1', 'NPM1', 'DDX50', 'HDAC6', 'TARDBP', 'PTBP1', 'DDX3X', 'NOP58', 'SNRPD1', 'BAG2', 'DDX52', 'U2SURP', 'HNRNPM', 'DNALI1', 'EEF1A1', 'NONO', 'GCN1', 'TMPO', 'RSL1D1', 'ACIN1', 'TTN', 'RBM39', 'DHRS7B', 'PRKCA', 'YWHAG', 'SETDB1', 'KAT5', 'LMO3', 'GTPBP10', 'MRPL58', 'CAND1', 'GOLGA2', 'PNMA1', 'PCBP4', 'MRPS30', 'RCC1L', 'BPNT1', 'MRPL50', 'MECP2', 'SUCLA2', 'PLEKHO1', 'PTPN2', 'EFTUD2', 'HABP4', 'SERBP1', 'MRM1', 'TRMT61B', 'IRF2', 'SNRNP70', 'H2BC21', 'ESR1', 'IMMP2L', 'GRSF1', 'ACAD9', 'AUH', 'C12orf65', 'C1QBP', 'MTRES1', 'CHCHD1', 'CS', 'GFM1', 'GFM2', 'LRPPRC', 'MDH2', 'METTL15', 'METTL17', 'MRPL11', 'MRPS12', 'MRPS26', 'MRRF', 'MTERF3', 'MTG1', 'MTIF2', 'MTIF3', 'MTRF1', 'MTRF1L', 'PMPCA', 'PMPCB', 'RPUSD4', 'SSBP1', 'TACO1', 'TRUB2', 'TSFM', 'TUFM', 'EXD2', 'CLPP', 'LGALS9', 'MGST3', 'ATAD3B', 'ATAD3A', 'VPS37C', 'UBC', 'MVB12A', 'TLE5', 'XIAP', 'DDIT3', 'PKNOX1', 'PLSCR1', 'SH3GL1', 'SORBS2', 'DAZAP2', 'SORBS3', 'STAM2', 'TFG', 'RBPMS', 'WWP2', 'HNRNPUL1', 'FAM168A', 'TFIP11', 'RINT1', 'MAPK1IP1L', 'HOXB5', 'TRIM14', 'TNIP2', 'AGO2', 'LASP1', 'POLR2J', 'ZMYND12', 'BIRC7', 'RPRD1B', 'KLF1', 'ABHD11', 'POU2AF1', 'ILF3', 'CBFA2T3', 'GPS2', 'UBAP2', 'DCTN3', 'FCHSD2', 'NUP54', 'YTHDF1', 'TIAL1', 'HAUS1', 'SH3RF1', 'BAG4', 'NTAQ1', 'PEF1', 'FUBP1', 'PKNOX2', 'TSC1', 'RAMAC', 'HNRNPF', 'HYI', 'WWOX', 'PLEKHG4', 'ZNF34', 'LAGE3', 'STH', 'ARHGEF6', 'PARP2', 'PDLIM7', 'CNOT1', 'USP22', 'GTF2A1', 'SIRT7', 'NOTCH1', 'EPAS1', 'FN1', 'PEX14', 'PPP6R1', 'KRT18', 'POLR1C', 'OBI1', 'FBXW11', 'TNRC6A', 'RXRA', 'CCDC8', 'MMP7', 'CAPZA2', 'TNRC6B', 'IFI16', 'BTRC', 'MED4', 'SSX2IP', 'CNTROB', 'NINL', 'CENPJ', 'XPO1', 'ABCF1', 'ATRX', 'CAPZA1', 'CAPZB', 'FHL2', 'RPS27', 'SDCBP', 'TOB2', 'BTG3', 'NUP42', 'REEP5', 'BAG6', 'IBTK', 'SND1', 'AURKAIP1', 'PI4K2A', 'GPBP1L1', 'INTS5', 'TNKS1BP1', 'RAVER1', 'DDX6', 'SNW1', 'CDC5L', 'RC3H1', 'GADD45B', 'TRIM25', 'G3BP1', 'HNRNPL', 'STK40', 'FBXO7', 'HIF1AN', 'EGLN3', 'RMND5A', 'RNF4', 'POLR2A', 'ESR2', 'RNF123', 'AGR2', 'SUZ12', 'MED14', 'WDR76', 'GRWD1', 'VIRMA', 'RC3H2', 'ZC3H7A', 'TANK', 'USP14', 'DYRK1A', 'ANXA2R', 'LGALS3BP', 'BIRC3', 'STAU1', 'TRIM28', 'MIB1', 'ANKRD55', 'ANKRD17', 'CAPRIN1', 'CEP85', 'FAM193A', 'GPBP1', 'CPEB4', 'CSDE1', 'CTIF', 'EIF4ENIF1', 'FAM120C', 'FUBP3', 'FXR2', 'GARRE1', 'LSM14A', 'LZTS2', 'MKRN2', 'MOV10', 'NUFIP2', 'PABPC1', 'PAIP1', 'PAIP2', 'PATL1', 'PRRC2A', 'PUM1', 'R3HDM2', 'RBMS1', 'SAMD4B', 'ENTR1', 'SMAP2', 'SMG7', 'TDRD3', 'UBAP2L', 'UNK', 'YTHDF2', 'YTHDF3', 'ZC3HAV1', 'ZFP36', 'TUBB3', 'TXNL1', 'PRRC2B', 'SMG6', 'LRRC59', 'CDC42', 'THRB', 'VCAM1', 'JUN', 'KSR1', 'LRRK2', 'ZDHHC5', 'RARA', 'PPARG', 'FAM83G', 'YWHAQ', 'SH3KBP1', 'SMAD3', 'CSNK1A1', 'NXF1', 'VAPB', 'YWHAH', 'VAPA', 'CRBN', 'NIN', 'YWHAB', 'CSNK1D', 'CSNK1E', 'WIPF3', 'DNMBP', 'NCK2', 'ACTC1', 'ITSN1', 'ITSN2', 'VSTM2L', 'ARHGAP32', 'SFN', 'GAB2', 'GAB1', 'ARRB1', 'FZR1', 'SMURF1', 'DZIP3', 'ABI2', 'ZWINT', 'HNRNPD', 'SORT1', 'SYNCRIP', 'SGTB', 'PTPRK', 'ASB3', 'BICD1', 'OBSL1', 'CUL7', 'GPHN', 'SEC61B', 'CBS', 'PRDX4', 'SEC16A', 'ADAM10', 'GRAP', 'SFI1', 'KRT19', 'CETN2', 'LPXN', 'MAD2L2', 'SERTAD1', 'CCDC57', 'CETN1', 'USP9X', 'LMNB2', 'PPP1CA', 'MIF4GD', 'HGS', 'DDX19A', 'SVIL', 'UBQLN4', 'HINFP', 'DHX16', 'ILF2', 'PDXDC1', 'LSM5', 'HDAC4', 'EXOSC6', 'PDE4DIP', 'PSMC1', 'SLBP', 'BMT2', 'SMARCB1', 'APEX1', 'CHCHD2', 'ENKD1', 'FAM110A', 'EIF3G', 'ATPAF2', 'AQP1' ...
# <class 'networkx.classes.reportviews.NodeView'>

# %%
H = nx.read_graphml('HEK293T_SARS-CoV-2.graphml')
nx.draw(H)
plt.show()

count=0
for edge in H.edges(data=True):
  count=count+1
  print(edge)
print(count)


nodes = H.nodes(data=True)
count=0
for src, tgt, attr in H.edges(data=True):
  count=count+1
  # print type(node1)
  src_attr = nodes[src]
  tgt_attr = nodes[tgt]
  ###### print(str(src) + ' - ' + str(tgt) + ' : ' + attr['name'] + ' : ' + src_attr['name'] + ' , ' + tgt_attr['name'])
  # print(src_attr['name'] + ' , ' + tgt_attr['name'])
  textDATA=src_attr['name'] + '\t' + tgt_attr['name']
  print(textDATA)
print(count)
# Here is some basic information about the graph using nx.info(G):
print(nx.info(H))
#######################################################################################################################################
import networkx as nx
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
import csv
import numpy as np
from pandas import DataFrame

fields = ['name1', 'name2']
data = pd.read_csv('SARS-Cov2-VirHostPPIData.txt', usecols=fields, sep="\t")


# convert to dataframe using the first row as the column names; drop empty, final row
df = pd.DataFrame(data[1:-1], columns = ['name1','name2']) 
# # dataframe with the preferred names of the two proteins and the score of the interaction
interactions = df[['name1','name2']]

I=nx.Graph(name='SARS Cov2 VirHostPPIData')
interactions = np.array(interactions)
for i in range(len(interactions)):
    interaction = interactions[i]
    a = interaction[0] # protein a node
    b = interaction[1] # protein b node
    #w = float(interaction[2]) # score as weighted edge where high scores = low weight
    #G.add_weighted_edges_from([(a,b)]) # add weighted edge to graph
    I.add_edges_from([(a,b)])

nx.draw(I)
plt.show()

# ##########################################################################################

for edge in I.edges(data=True):
  print(edge)



for node in I.nodes(data=True):
  print(node)

#########################################

# Here is some basic information about the graph using nx.info(G):
print(nx.info(I))
# Out:
# ('1612', '1668', {'SUID': 3377, 'shared name': 'PPIL3 (interacts with) SLU7', 'shared interaction': 'interacts with', 'name': 'PPIL3 (interacts with) SLU7', 'selected': False, 'interaction': 'interacts with', 'FoldChange': 0.0, 'BFDR': nan, 'Complex': 'Spliceosome;C complex spliceosome'})
# ('1604', '1444', {'SUID': 3373, 'shared name': 'Nsp13 (interacts with) NINL', 'shared interaction': 'interacts with', 'name': 'nsp13 (interacts with) NINL', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q9Y2I6', 'MIST': 0.987790569, 'FoldChange': 453.33, 'BFDR': 0.0, 'AvgSpec': 45.33, 'Complex': 'NaN'})
# ('1604', '1448', {'SUID': 3369, 'shared name': 'Nsp13 (interacts with) HOOK1', 'shared interaction': 'interacts with', 'name': 'nsp13 (interacts with) HOOK1', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q9UJC3', 'MIST': 0.994048081, 'FoldChange': 240.0, 'BFDR': 0.0, 'AvgSpec': 24.0, 'Complex': 'NaN'})
# ('1604', '1452', {'SUID': 3365, 'shared name': 'Nsp13 (interacts with) TBK1', 'shared interaction': 'interacts with', 'name': 'nsp13 (interacts with) TBK1', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q9UHD2', 'MIST': 0.993970596, 'FoldChange': 70.0, 'BFDR': 0.0, 'AvgSpec': 7.0, 'Complex': 'NaN'})
# ('1604', '1456', {'SUID': 3361, 'shared name': 'Nsp13 (interacts with) CEP250', 'shared interaction': 'interacts with', 'name': 'nsp13 (interacts with) CEP250', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q9BV73', 'MIST': 0.990717833, 'FoldChange': 1510.0, 'BFDR': 0.0, 'AvgSpec': 151.0, 'Complex': 'NaN'})
# ('1604', '1460', {'SUID': 3357, 'shared name': 'Nsp13 (interacts with) C1orf50', 'shared interaction': 'interacts with', 'name': 'nsp13 (interacts with) C1orf50', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q9BV19', 'MIST': 0.932056845, 'FoldChange': 40.0, 'BFDR': 0.0, 'AvgSpec': 4.0, 'Complex': 'NaN'})
# ('1604', '1464', {'SUID': 3353, 'shared name': 'Nsp13 (interacts with) FYCO1', 'shared interaction': 'interacts with', 'name': 'nsp13 (interacts with) FYCO1', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q9BQS8', 'MIST': 0.733173301, 'FoldChange': 20.0, 'BFDR': 0.05, 'AvgSpec': 2.0, 'Complex': 'NaN'})
# ('1604', '1468', {'SUID': 3349, 'shared name': 'Nsp13 (interacts with) GORASP1', 'shared interaction': 'interacts with', 'name': 'nsp13 (interacts with) GORASP1', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q9BQQ3', 'MIST': 0.986870312, 'FoldChange': 53.33, 'BFDR': 0.0, 'AvgSpec': 5.33, 'Complex': 'NaN'})
# ('1604', '1472', {'SUID': 3345, 'shared name': 'Nsp13 (interacts with) AKAP9', 'shared interaction': 'interacts with', 'name': 'nsp13 (interacts with) AKAP9', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q99996', 'MIST': 0.990813809, 'FoldChange': 1090.0, 'BFDR': 0.0, 'AvgSpec': 109.0, 'Complex': 'NaN'})
# ('1604', '1476', {'SUID': 3341, 'shared name': 'Nsp13 (interacts with) CDK5RAP2', 'shared interaction': 'interacts with', 'name': 'nsp13 (interacts with) CDK5RAP2', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q96SN8', 'MIST': 0.939307247, 'FoldChange': 626.67, 'BFDR': 0.0, 'AvgSpec': 62.67, 'Complex': 'NaN'})
# ('1604', '1480', {'SUID': 3337, 'shared name': 'Nsp13 (interacts with) JAKMIP1', 'shared interaction': 'interacts with', 'name': 'nsp13 (interacts with) JAKMIP1', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q96N16', 'MIST': 0.987966991, 'FoldChange': 146.67, 'BFDR': 0.0, 'AvgSpec': 14.67, 'Complex': 'NaN'})
# ('1604', '1484', {'SUID': 3333, 'shared name': 'Nsp13 (interacts with) GCC1', 'shared interaction': 'interacts with', 'name': 'nsp13 (interacts with) GCC1', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q96CN9', 'MIST': 0.873361571, 'FoldChange': 96.67, 'BFDR': 0.0, 'AvgSpec': 9.67, 'Complex': 'NaN'})
# ('1604', '1488', {'SUID': 3329, 'shared name': 'Nsp13 (interacts with) USP13', 'shared interaction': 'interacts with', 'name': 'nsp13 (interacts with) USP13', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q92995', 'MIST': 0.987514452, 'FoldChange': 103.33, 'BFDR': 0.0, 'AvgSpec': 10.33, 'Complex': 'NaN'})
# ('1604', '1492', {'SUID': 3325, 'shared name': 'Nsp13 (interacts with) MIPOL1', 'shared interaction': 'interacts with', 'name': 'nsp13 (interacts with) MIPOL1', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q8TD10', 'MIST': 0.98176996, 'FoldChange': 180.0, 'BFDR': 0.0, 'AvgSpec': 18.0, 'Complex': 'NaN'})
# ('1604', '1496', {'SUID': 3321, 'shared name': 'Nsp13 (interacts with) CEP112', 'shared interaction': 'interacts with', 'name': 'nsp13 (interacts with) CEP112', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q8N8E3', 'MIST': 0.964318835, 'FoldChange': 23.33, 'BFDR': 0.05, 'AvgSpec': 2.33, 'Complex': 'NaN'})
# ('1604', '1500', {'SUID': 3317, 'shared name': 'Nsp13 (interacts with) NIN', 'shared interaction': 'interacts with', 'name': 'nsp13 (interacts with) NIN', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q8N4C6', 'MIST': 0.991583194, 'FoldChange': 690.0, 'BFDR': 0.0, 'AvgSpec': 69.0, 'Complex': 'NaN'})
# ('1604', '1504', {'SUID': 3313, 'shared name': 'Nsp13 (interacts with) CLIP4', 'shared interaction': 'interacts with', 'name': 'nsp13 (interacts with) CLIP4', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q8N3C7', 'MIST': 0.966944672, 'FoldChange': 36.67, 'BFDR': 0.0, 'AvgSpec': 3.67, 'Complex': 'NaN'})
# ('1604', '1508', {'SUID': 3309, 'shared name': 'Nsp13 (interacts with) GCC2', 'shared interaction': 'interacts with', 'name': 'nsp13 (interacts with) GCC2', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q8IWJ2', 'MIST': 0.987387119, 'FoldChange': 46.67, 'BFDR': 0.0, 'AvgSpec': 4.67, 'Complex': 'NaN'})
# ('1604', '1512', {'SUID': 3305, 'shared name': 'Nsp13 (interacts with) ERC1', 'shared interaction': 'interacts with', 'name': 'nsp13 (interacts with) ERC1', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q8IUD2', 'MIST': 0.990718127, 'FoldChange': 240.0, 'BFDR': 0.0, 'AvgSpec': 24.0, 'Complex': 'NaN'})
# ('1604', '1516', {'SUID': 3301, 'shared name': 'Nsp13 (interacts with) CNTRL', 'shared interaction': 'interacts with', 'name': 'nsp13 (interacts with) CNTRL', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q7Z7A1', 'MIST': 0.989917408, 'FoldChange': 50.0, 'BFDR': 0.0, 'AvgSpec': 5.0, 'Complex': 'NaN'})
# ('1604', '1520', {'SUID': 3297, 'shared name': 'Nsp13 (interacts with) CEP68', 'shared interaction': 'interacts with', 'name': 'nsp13 (interacts with) CEP68', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q76N32', 'MIST': 0.879704216, 'FoldChange': 30.0, 'BFDR': 0.03, 'AvgSpec': 3.0, 'Complex': 'NaN'})
# ('1604', '1524', {'SUID': 3293, 'shared name': 'Nsp13 (interacts with) CEP135', 'shared interaction': 'interacts with', 'name': 'nsp13 (interacts with) CEP135', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q66GS9', 'MIST': 0.975292134, 'FoldChange': 63.33, 'BFDR': 0.0, 'AvgSpec': 6.33, 'Complex': 'NaN'})
# ('1604', '1528', {'SUID': 3289, 'shared name': 'Nsp13 (interacts with) PDE4DIP', 'shared interaction': 'interacts with', 'name': 'nsp13 (interacts with) PDE4DIP', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q5VU43', 'MIST': 0.979124391, 'FoldChange': 236.67, 'BFDR': 0.0, 'AvgSpec': 23.67, 'Complex': 'NaN'})
# ('1604', '1532', {'SUID': 3285, 'shared name': 'Nsp13 (interacts with) CEP350', 'shared interaction': 'interacts with', 'name': 'nsp13 (interacts with) CEP350', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q5VT06', 'MIST': 0.86755993, 'FoldChange': 56.67, 'BFDR': 0.0, 'AvgSpec': 5.67, 'Complex': 'NaN'})
# ('1604', '1536', {'SUID': 3281, 'shared name': 'Nsp13 (interacts with) GRIPAP1', 'shared interaction': 'interacts with', 'name': 'nsp13 (interacts with) GRIPAP1', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q4V328', 'MIST': 0.989815969, 'FoldChange': 310.0, 'BFDR': 0.0, 'AvgSpec': 31.0, 'Complex': 'NaN'})
# ('1604', '1540', {'SUID': 3277, 'shared name': 'Nsp13 (interacts with) GOLGB1', 'shared interaction': 'interacts with', 'name': 'nsp13 (interacts with) GOLGB1', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q14789', 'MIST': 0.985604541, 'FoldChange': 900.0, 'BFDR': 0.0, 'AvgSpec': 90.0, 'Complex': 'NaN'})
# ('1604', '1544', {'SUID': 3273, 'shared name': 'Nsp13 (interacts with) GOLGA2', 'shared interaction': 'interacts with', 'name': 'nsp13 (interacts with) GOLGA2', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q08379', 'MIST': 0.952311087, 'FoldChange': 773.33, 'BFDR': 0.0, 'AvgSpec': 77.33, 'Complex': 'NaN'})
# ('1604', '1548', {'SUID': 3269, 'shared name': 'Nsp13 (interacts with) GOLGA3', 'shared interaction': 'interacts with', 'name': 'nsp13 (interacts with) GOLGA3', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q08378', 'MIST': 0.928738823, 'FoldChange': 850.0, 'BFDR': 0.0, 'AvgSpec': 85.0, 'Complex': 'NaN'})
# ('1604', '1552', {'SUID': 3265, 'shared name': 'Nsp13 (interacts with) TLE5', 'shared interaction': 'interacts with', 'name': 'nsp13 (interacts with) TLE5', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q08117', 'MIST': 0.962431031, 'FoldChange': 23.33, 'BFDR': 0.04, 'AvgSpec': 2.33, 'Complex': 'NaN'})
# ('1604', '1556', {'SUID': 3261, 'shared name': 'Nsp13 (interacts with) TLE3', 'shared interaction': 'interacts with', 'name': 'nsp13 (interacts with) TLE3', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q04726', 'MIST': 0.933626993, 'FoldChange': 180.0, 'BFDR': 0.0, 'AvgSpec': 18.0, 'Complex': 'NaN'})
# ('1604', '1560', {'SUID': 3257, 'shared name': 'Nsp13 (interacts with) TLE1', 'shared interaction': 'interacts with', 'name': 'nsp13 (interacts with) TLE1', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q04724', 'MIST': 0.96917283, 'FoldChange': 43.33, 'BFDR': 0.0, 'AvgSpec': 4.33, 'Complex': 'NaN'})
# ('1604', '1564', {'SUID': 3253, 'shared name': 'Nsp13 (interacts with) CENPF', 'shared interaction': 'interacts with', 'name': 'nsp13 (interacts with) CENPF', 'selected': False, 'interaction': 'interacts with', 'Preys': 'P49454', 'MIST': 0.873840643, 'FoldChange': 200.0, 'BFDR': 0.0, 'AvgSpec': 20.0, 'Complex': 'NaN'})
# ('1604', '1568', {'SUID': 3249, 'shared name': 'Nsp13 (interacts with) RDX', 'shared interaction': 'interacts with', 'name': 'nsp13 (interacts with) RDX', 'selected': False, 'interaction': 'interacts with', 'Preys': 'P35241', 'MIST': 0.912028315, 'FoldChange': 70.0, 'BFDR': 0.0, 'AvgSpec': 7.0, 'Complex': 'NaN'})
# ('1604', '1572', {'SUID': 3245, 'shared name': 'Nsp13 (interacts with) PRKAR2B', 'shared interaction': 'interacts with', 'name': 'nsp13 (interacts with) PRKAR2B', 'selected': False, 'interaction': 'interacts with', 'Preys': 'P31323', 'MIST': 0.983191506, 'FoldChange': 66.67, 'BFDR': 0.0, 'AvgSpec': 6.67, 'Complex': 'NaN'})
# ('1604', '1576', {'SUID': 3241, 'shared name': 'Nsp13 (interacts with) PRKACA', 'shared interaction': 'interacts with', 'name': 'nsp13 (interacts with) PRKACA', 'selected': False, 'interaction': 'interacts with', 'Preys': 'P17612', 'MIST': 0.880321174, 'FoldChange': 53.33, 'BFDR': 0.0, 'AvgSpec': 5.33, 'Complex': 'NaN'})
# ('1604', '1580', {'SUID': 3237, 'shared name': 'Nsp13 (interacts with) PRKAR2A', 'shared interaction': 'interacts with', 'name': 'nsp13 (interacts with) PRKAR2A', 'selected': False, 'interaction': 'interacts with', 'Preys': 'P13861', 'MIST': 0.897857211, 'FoldChange': 200.0, 'BFDR': 0.0, 'AvgSpec': 20.0, 'Complex': 'NaN'})
# ('1604', '1584', {'SUID': 3233, 'shared name': 'Nsp13 (interacts with) CEP43', 'shared interaction': 'interacts with', 'name': 'nsp13 (interacts with) CEP43', 'selected': False, 'interaction': 'interacts with', 'Preys': 'O95684', 'MIST': 0.981570359, 'FoldChange': 20.0, 'BFDR': 0.05, 'AvgSpec': 2.0, 'Complex': 'NaN'})
# ('1604', '1588', {'SUID': 3229, 'shared name': 'Nsp13 (interacts with) PCNT', 'shared interaction': 'interacts with', 'name': 'nsp13 (interacts with) PCNT', 'selected': False, 'interaction': 'interacts with', 'Preys': 'O95613', 'MIST': 0.971855938, 'FoldChange': 1810.0, 'BFDR': 0.0, 'AvgSpec': 181.0, 'Complex': 'NaN'})
# ('1604', '1592', {'SUID': 3225, 'shared name': 'Nsp13 (interacts with) HSBP1', 'shared interaction': 'interacts with', 'name': 'nsp13 (interacts with) HSBP1', 'selected': False, 'interaction': 'interacts with', 'Preys': 'O75506', 'MIST': 0.851502614, 'FoldChange': 43.33, 'BFDR': 0.0, 'AvgSpec': 4.33, 'Complex': 'NaN'})
# ('1604', '1596', {'SUID': 3221, 'shared name': 'Nsp13 (interacts with) CIT', 'shared interaction': 'interacts with', 'name': 'nsp13 (interacts with) CIT', 'selected': False, 'interaction': 'interacts with', 'Preys': 'O14578', 'MIST': 0.887314876, 'FoldChange': 60.0, 'BFDR': 0.0, 'AvgSpec': 6.0, 'Complex': 'NaN'})
# ('1604', '1600', {'SUID': 3217, 'shared name': 'Nsp13 (interacts with) TBKBP1', 'shared interaction': 'interacts with', 'name': 'nsp13 (interacts with) TBKBP1', 'selected': False, 'interaction': 'interacts with', 'Preys': 'A7MCY6', 'MIST': 0.985289524, 'FoldChange': 63.33, 'BFDR': 0.0, 'AvgSpec': 6.33, 'Complex': 'NaN'})
# ('1588', '1500', {'SUID': 3213, 'shared name': 'PCNT (interacts with) NIN', 'shared interaction': 'interacts with', 'name': 'PCNT (interacts with) NIN', 'selected': False, 'interaction': 'interacts with'})
# ('1588', '1532', {'SUID': 3209, 'shared name': 'PCNT (interacts with) CEP350', 'shared interaction': 'interacts with', 'name': 'PCNT (interacts with) CEP350', 'selected': False, 'interaction': 'interacts with'})
# ('1588', '1524', {'SUID': 3205, 'shared name': 'PCNT (interacts with) CEP135', 'shared interaction': 'interacts with', 'name': 'PCNT (interacts with) CEP135', 'selected': False, 'interaction': 'interacts with'})
# ('1588', '1516', {'SUID': 3201, 'shared name': 'PCNT (interacts with) CNTRL', 'shared interaction': 'interacts with', 'name': 'PCNT (interacts with) CNTRL', 'selected': False, 'interaction': 'interacts with'})
# ('1588', '1456', {'SUID': 3197, 'shared name': 'PCNT (interacts with) CEP250', 'shared interaction': 'interacts with', 'name': 'PCNT (interacts with) CEP250', 'selected': False, 'interaction': 'interacts with'})
# ('1588', '1520', {'SUID': 3193, 'shared name': 'PCNT (interacts with) CEP68', 'shared interaction': 'interacts with', 'name': 'PCNT (interacts with) CEP68', 'selected': False, 'interaction': 'interacts with'})
# ('1588', '1496', {'SUID': 3189, 'shared name': 'PCNT (interacts with) CEP112', 'shared interaction': 'interacts with', 'name': 'PCNT (interacts with) CEP112', 'selected': False, 'interaction': 'interacts with'})
# ('1584', '1524', {'SUID': 3185, 'shared name': 'CEP43 (interacts with) CEP135', 'shared interaction': 'interacts with', 'name': 'CEP43 (interacts with) CEP135', 'selected': False, 'interaction': 'interacts with'})
# ('1584', '1520', {'SUID': 3181, 'shared name': 'CEP43 (interacts with) CEP68', 'shared interaction': 'interacts with', 'name': 'CEP43 (interacts with) CEP68', 'selected': False, 'interaction': 'interacts with'})
# ('1584', '1456', {'SUID': 3177, 'shared name': 'CEP43 (interacts with) CEP250', 'shared interaction': 'interacts with', 'name': 'CEP43 (interacts with) CEP250', 'selected': False, 'interaction': 'interacts with'})
# ('1584', '1532', {'SUID': 3173, 'shared name': 'CEP43 (interacts with) CEP350', 'shared interaction': 'interacts with', 'name': 'CEP43 (interacts with) CEP350', 'selected': False, 'interaction': 'interacts with'})
# ('1584', '1496', {'SUID': 3169, 'shared name': 'CEP43 (interacts with) CEP112', 'shared interaction': 'interacts with', 'name': 'CEP43 (interacts with) CEP112', 'selected': False, 'interaction': 'interacts with'})
# ('1584', '1564', {'SUID': 3165, 'shared name': 'CEP43 (interacts with) CENPF', 'shared interaction': 'interacts with', 'name': 'CEP43 (interacts with) CENPF', 'selected': False, 'interaction': 'interacts with'})
# ('1584', '1444', {'SUID': 3161, 'shared name': 'CEP43 (interacts with) NINL', 'shared interaction': 'interacts with', 'name': 'CEP43 (interacts with) NINL', 'selected': False, 'interaction': 'interacts with'})
# ('1584', '1588', {'SUID': 3157, 'shared name': 'CEP43 (interacts with) PCNT', 'shared interaction': 'interacts with', 'name': 'CEP43 (interacts with) PCNT', 'selected': False, 'interaction': 'interacts with'})
# ('1584', '1500', {'SUID': 3153, 'shared name': 'CEP43 (interacts with) NIN', 'shared interaction': 'interacts with', 'name': 'CEP43 (interacts with) NIN', 'selected': False, 'interaction': 'interacts with'})
# ('1584', '1516', {'SUID': 3149, 'shared name': 'CEP43 (interacts with) CNTRL', 'shared interaction': 'interacts with', 'name': 'CEP43 (interacts with) CNTRL', 'selected': False, 'interaction': 'interacts with'})
# ('1580', '1572', {'SUID': 3145, 'shared name': 'PRKAR2A (interacts with) PRKAR2B', 'shared interaction': 'interacts with', 'name': 'PRKAR2A (interacts with) PRKAR2B', 'selected': False, 'interaction': 'interacts with', 'FoldChange': 0.0, 'BFDR': nan, 'Complex': 'Yotiao-RII-NR1 complex;PKA (RII-alpha and RII-beta)-AKAP5-ADRB1 complex'})
# ('1576', '1580', {'SUID': 3141, 'shared name': 'PRKACA (interacts with) PRKAR2A', 'shared interaction': 'interacts with', 'name': 'PRKACA (interacts with) PRKAR2A', 'selected': False, 'interaction': 'interacts with', 'FoldChange': 0.0, 'BFDR': nan, 'Complex': 'PKA-RII-AKAP18gamma complex'})
# ('1564', '1532', {'SUID': 3137, 'shared name': 'CENPF (interacts with) CEP350', 'shared interaction': 'interacts with', 'name': 'CENPF (interacts with) CEP350', 'selected': False, 'interaction': 'interacts with'})
# ('1564', '1524', {'SUID': 3133, 'shared name': 'CENPF (interacts with) CEP135', 'shared interaction': 'interacts with', 'name': 'CENPF (interacts with) CEP135', 'selected': False, 'interaction': 'interacts with'})
# ('1564', '1456', {'SUID': 3129, 'shared name': 'CENPF (interacts with) CEP250', 'shared interaction': 'interacts with', 'name': 'CENPF (interacts with) CEP250', 'selected': False, 'interaction': 'interacts with'})
# ('1564', '1520', {'SUID': 3125, 'shared name': 'CENPF (interacts with) CEP68', 'shared interaction': 'interacts with', 'name': 'CENPF (interacts with) CEP68', 'selected': False, 'interaction': 'interacts with'})
# ('1564', '1496', {'SUID': 3121, 'shared name': 'CENPF (interacts with) CEP112', 'shared interaction': 'interacts with', 'name': 'CENPF (interacts with) CEP112', 'selected': False, 'interaction': 'interacts with'})
# ('1564', '1444', {'SUID': 3117, 'shared name': 'CENPF (interacts with) NINL', 'shared interaction': 'interacts with', 'name': 'CENPF (interacts with) NINL', 'selected': False, 'interaction': 'interacts with'})
# ('1564', '1588', {'SUID': 3113, 'shared name': 'CENPF (interacts with) PCNT', 'shared interaction': 'interacts with', 'name': 'CENPF (interacts with) PCNT', 'selected': False, 'interaction': 'interacts with'})
# ('1564', '1500', {'SUID': 3109, 'shared name': 'CENPF (interacts with) NIN', 'shared interaction': 'interacts with', 'name': 'CENPF (interacts with) NIN', 'selected': False, 'interaction': 'interacts with'})
# ('1564', '1516', {'SUID': 3105, 'shared name': 'CENPF (interacts with) CNTRL', 'shared interaction': 'interacts with', 'name': 'CENPF (interacts with) CNTRL', 'selected': False, 'interaction': 'interacts with'})
# ('1560', '1556', {'SUID': 3101, 'shared name': 'TLE1 (interacts with) TLE3', 'shared interaction': 'interacts with', 'name': 'TLE1 (interacts with) TLE3', 'selected': False, 'interaction': 'interacts with'})
# ('1560', '1552', {'SUID': 3097, 'shared name': 'TLE1 (interacts with) TLE5', 'shared interaction': 'interacts with', 'name': 'TLE1 (interacts with) TLE5', 'selected': False, 'interaction': 'interacts with'})
# ('1556', '1552', {'SUID': 3093, 'shared name': 'TLE3 (interacts with) TLE5', 'shared interaction': 'interacts with', 'name': 'TLE3 (interacts with) TLE5', 'selected': False, 'interaction': 'interacts with'})
# ('1532', '1496', {'SUID': 3089, 'shared name': 'CEP350 (interacts with) CEP112', 'shared interaction': 'interacts with', 'name': 'CEP350 (interacts with) CEP112', 'selected': False, 'interaction': 'interacts with'})
# ('1532', '1516', {'SUID': 3085, 'shared name': 'CEP350 (interacts with) CNTRL', 'shared interaction': 'interacts with', 'name': 'CEP350 (interacts with) CNTRL', 'selected': False, 'interaction': 'interacts with'})
# ('1524', '1520', {'SUID': 3081, 'shared name': 'CEP135 (interacts with) CEP68', 'shared interaction': 'interacts with', 'name': 'CEP135 (interacts with) CEP68', 'selected': False, 'interaction': 'interacts with'})
# ('1524', '1456', {'SUID': 3077, 'shared name': 'CEP135 (interacts with) CEP250', 'shared interaction': 'interacts with', 'name': 'CEP135 (interacts with) CEP250', 'selected': False, 'interaction': 'interacts with'})
# ('1524', '1532', {'SUID': 3073, 'shared name': 'CEP135 (interacts with) CEP350', 'shared interaction': 'interacts with', 'name': 'CEP135 (interacts with) CEP350', 'selected': False, 'interaction': 'interacts with'})
# ('1524', '1496', {'SUID': 3069, 'shared name': 'CEP135 (interacts with) CEP112', 'shared interaction': 'interacts with', 'name': 'CEP135 (interacts with) CEP112', 'selected': False, 'interaction': 'interacts with'})
# ('1524', '1516', {'SUID': 3065, 'shared name': 'CEP135 (interacts with) CNTRL', 'shared interaction': 'interacts with', 'name': 'CEP135 (interacts with) CNTRL', 'selected': False, 'interaction': 'interacts with'})
# ('1520', '1456', {'SUID': 3061, 'shared name': 'CEP68 (interacts with) CEP250', 'shared interaction': 'interacts with', 'name': 'CEP68 (interacts with) CEP250', 'selected': False, 'interaction': 'interacts with'})
# ('1520', '1532', {'SUID': 3057, 'shared name': 'CEP68 (interacts with) CEP350', 'shared interaction': 'interacts with', 'name': 'CEP68 (interacts with) CEP350', 'selected': False, 'interaction': 'interacts with'})
# ('1520', '1496', {'SUID': 3053, 'shared name': 'CEP68 (interacts with) CEP112', 'shared interaction': 'interacts with', 'name': 'CEP68 (interacts with) CEP112', 'selected': False, 'interaction': 'interacts with'})
# ('1516', '1456', {'SUID': 3049, 'shared name': 'CNTRL (interacts with) CEP250', 'shared interaction': 'interacts with', 'name': 'CNTRL (interacts with) CEP250', 'selected': False, 'interaction': 'interacts with'})
# ('1516', '1520', {'SUID': 3045, 'shared name': 'CNTRL (interacts with) CEP68', 'shared interaction': 'interacts with', 'name': 'CNTRL (interacts with) CEP68', 'selected': False, 'interaction': 'interacts with'})
# ('1516', '1496', {'SUID': 3041, 'shared name': 'CNTRL (interacts with) CEP112', 'shared interaction': 'interacts with', 'name': 'CNTRL (interacts with) CEP112', 'selected': False, 'interaction': 'interacts with'})
# ('1500', '1532', {'SUID': 3037, 'shared name': 'NIN (interacts with) CEP350', 'shared interaction': 'interacts with', 'name': 'NIN (interacts with) CEP350', 'selected': False, 'interaction': 'interacts with'})
# ('1500', '1524', {'SUID': 3033, 'shared name': 'NIN (interacts with) CEP135', 'shared interaction': 'interacts with', 'name': 'NIN (interacts with) CEP135', 'selected': False, 'interaction': 'interacts with'})
# ('1500', '1516', {'SUID': 3029, 'shared name': 'NIN (interacts with) CNTRL', 'shared interaction': 'interacts with', 'name': 'NIN (interacts with) CNTRL', 'selected': False, 'interaction': 'interacts with'})
# ('1500', '1456', {'SUID': 3025, 'shared name': 'NIN (interacts with) CEP250', 'shared interaction': 'interacts with', 'name': 'NIN (interacts with) CEP250', 'selected': False, 'interaction': 'interacts with'})
# ('1500', '1520', {'SUID': 3021, 'shared name': 'NIN (interacts with) CEP68', 'shared interaction': 'interacts with', 'name': 'NIN (interacts with) CEP68', 'selected': False, 'interaction': 'interacts with'})
# ('1500', '1496', {'SUID': 3017, 'shared name': 'NIN (interacts with) CEP112', 'shared interaction': 'interacts with', 'name': 'NIN (interacts with) CEP112', 'selected': False, 'interaction': 'interacts with'})
# ('1476', '1584', {'SUID': 3013, 'shared name': 'CDK5RAP2 (interacts with) CEP43', 'shared interaction': 'interacts with', 'name': 'CDK5RAP2 (interacts with) CEP43', 'selected': False, 'interaction': 'interacts with'})
# ('1476', '1564', {'SUID': 3009, 'shared name': 'CDK5RAP2 (interacts with) CENPF', 'shared interaction': 'interacts with', 'name': 'CDK5RAP2 (interacts with) CENPF', 'selected': False, 'interaction': 'interacts with'})
# ('1476', '1444', {'SUID': 3005, 'shared name': 'CDK5RAP2 (interacts with) NINL', 'shared interaction': 'interacts with', 'name': 'CDK5RAP2 (interacts with) NINL', 'selected': False, 'interaction': 'interacts with'})
# ('1476', '1588', {'SUID': 3001, 'shared name': 'CDK5RAP2 (interacts with) PCNT', 'shared interaction': 'interacts with', 'name': 'CDK5RAP2 (interacts with) PCNT', 'selected': False, 'interaction': 'interacts with'})
# ('1476', '1500', {'SUID': 2997, 'shared name': 'CDK5RAP2 (interacts with) NIN', 'shared interaction': 'interacts with', 'name': 'CDK5RAP2 (interacts with) NIN', 'selected': False, 'interaction': 'interacts with'})
# ('1476', '1532', {'SUID': 2993, 'shared name': 'CDK5RAP2 (interacts with) CEP350', 'shared interaction': 'interacts with', 'name': 'CDK5RAP2 (interacts with) CEP350', 'selected': False, 'interaction': 'interacts with'})
# ('1476', '1524', {'SUID': 2989, 'shared name': 'CDK5RAP2 (interacts with) CEP135', 'shared interaction': 'interacts with', 'name': 'CDK5RAP2 (interacts with) CEP135', 'selected': False, 'interaction': 'interacts with'})
# ('1476', '1516', {'SUID': 2985, 'shared name': 'CDK5RAP2 (interacts with) CNTRL', 'shared interaction': 'interacts with', 'name': 'CDK5RAP2 (interacts with) CNTRL', 'selected': False, 'interaction': 'interacts with'})
# ('1476', '1456', {'SUID': 2981, 'shared name': 'CDK5RAP2 (interacts with) CEP250', 'shared interaction': 'interacts with', 'name': 'CDK5RAP2 (interacts with) CEP250', 'selected': False, 'interaction': 'interacts with'})
# ('1476', '1520', {'SUID': 2977, 'shared name': 'CDK5RAP2 (interacts with) CEP68', 'shared interaction': 'interacts with', 'name': 'CDK5RAP2 (interacts with) CEP68', 'selected': False, 'interaction': 'interacts with'})
# ('1476', '1496', {'SUID': 2973, 'shared name': 'CDK5RAP2 (interacts with) CEP112', 'shared interaction': 'interacts with', 'name': 'CDK5RAP2 (interacts with) CEP112', 'selected': False, 'interaction': 'interacts with'})
# ('1472', '1572', {'SUID': 2969, 'shared name': 'AKAP9 (interacts with) PRKAR2B', 'shared interaction': 'interacts with', 'name': 'AKAP9 (interacts with) PRKAR2B', 'selected': False, 'interaction': 'interacts with', 'FoldChange': 0.0, 'BFDR': nan, 'Complex': 'Yotiao-RII-NR1 complex'})
# ('1472', '1580', {'SUID': 2965, 'shared name': 'AKAP9 (interacts with) PRKAR2A', 'shared interaction': 'interacts with', 'name': 'AKAP9 (interacts with) PRKAR2A', 'selected': False, 'interaction': 'interacts with', 'FoldChange': 0.0, 'BFDR': nan, 'Complex': 'KCNQ1 macromolecular complex;Yotiao-RII-NR1 complex'})
# ('1472', '1576', {'SUID': 2961, 'shared name': 'AKAP9 (interacts with) PRKACA', 'shared interaction': 'interacts with', 'name': 'AKAP9 (interacts with) PRKACA', 'selected': False, 'interaction': 'interacts with', 'FoldChange': 0.0, 'BFDR': nan, 'Complex': 'KCNQ1 macromolecular complex'})
# ('1456', '1532', {'SUID': 2957, 'shared name': 'CEP250 (interacts with) CEP350', 'shared interaction': 'interacts with', 'name': 'CEP250 (interacts with) CEP350', 'selected': False, 'interaction': 'interacts with'})
# ('1456', '1496', {'SUID': 2953, 'shared name': 'CEP250 (interacts with) CEP112', 'shared interaction': 'interacts with', 'name': 'CEP250 (interacts with) CEP112', 'selected': False, 'interaction': 'interacts with'})
# ('1452', '1600', {'SUID': 2949, 'shared name': 'TBK1 (interacts with) TBKBP1', 'shared interaction': 'interacts with', 'name': 'TBK1 (interacts with) TBKBP1', 'selected': False, 'interaction': 'interacts with', 'FoldChange': 0.0, 'BFDR': nan, 'Complex': 'Kinase maturation complex 2'})
# ('1444', '1588', {'SUID': 2945, 'shared name': 'NINL (interacts with) PCNT', 'shared interaction': 'interacts with', 'name': 'NINL (interacts with) PCNT', 'selected': False, 'interaction': 'interacts with'})
# ('1444', '1500', {'SUID': 2941, 'shared name': 'NINL (interacts with) NIN', 'shared interaction': 'interacts with', 'name': 'NINL (interacts with) NIN', 'selected': False, 'interaction': 'interacts with'})
# ('1444', '1532', {'SUID': 2937, 'shared name': 'NINL (interacts with) CEP350', 'shared interaction': 'interacts with', 'name': 'NINL (interacts with) CEP350', 'selected': False, 'interaction': 'interacts with'})
# ('1444', '1524', {'SUID': 2933, 'shared name': 'NINL (interacts with) CEP135', 'shared interaction': 'interacts with', 'name': 'NINL (interacts with) CEP135', 'selected': False, 'interaction': 'interacts with'})
# ('1444', '1516', {'SUID': 2929, 'shared name': 'NINL (interacts with) CNTRL', 'shared interaction': 'interacts with', 'name': 'NINL (interacts with) CNTRL', 'selected': False, 'interaction': 'interacts with'})
# ('1444', '1456', {'SUID': 2925, 'shared name': 'NINL (interacts with) CEP250', 'shared interaction': 'interacts with', 'name': 'NINL (interacts with) CEP250', 'selected': False, 'interaction': 'interacts with'})
# ('1444', '1520', {'SUID': 2921, 'shared name': 'NINL (interacts with) CEP68', 'shared interaction': 'interacts with', 'name': 'NINL (interacts with) CEP68', 'selected': False, 'interaction': 'interacts with'})
# ('1444', '1496', {'SUID': 2917, 'shared name': 'NINL (interacts with) CEP112', 'shared interaction': 'interacts with', 'name': 'NINL (interacts with) CEP112', 'selected': False, 'interaction': 'interacts with'})
# ('1440', '1428', {'SUID': 2913, 'shared name': 'Nsp14 (interacts with) SIRT5', 'shared interaction': 'interacts with', 'name': 'nsp14 (interacts with) SIRT5', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q9NXA8', 'MIST': 0.99363281, 'FoldChange': 116.67, 'BFDR': 0.0, 'AvgSpec': 11.67, 'Complex': 'NaN'})
# ('1440', '1432', {'SUID': 2909, 'shared name': 'Nsp14 (interacts with) IMPDH2', 'shared interaction': 'interacts with', 'name': 'nsp14 (interacts with) IMPDH2', 'selected': False, 'interaction': 'interacts with', 'Preys': 'P12268', 'MIST': 0.989667608, 'FoldChange': 183.33, 'BFDR': 0.0, 'AvgSpec': 18.33, 'Complex': 'NaN'})
# ('1440', '1436', {'SUID': 2905, 'shared name': 'Nsp14 (interacts with) GLA', 'shared interaction': 'interacts with', 'name': 'nsp14 (interacts with) GLA', 'selected': False, 'interaction': 'interacts with', 'Preys': 'P06280', 'MIST': 0.841137578, 'FoldChange': 256.67, 'BFDR': 0.0, 'AvgSpec': 25.67, 'Complex': 'NaN'})
# ('1424', '1412', {'SUID': 2901, 'shared name': 'Nsp15 (interacts with) RNF41', 'shared interaction': 'interacts with', 'name': 'nsp15 (interacts with) RNF41', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q9H4P4', 'MIST': 0.993560817, 'FoldChange': 213.33, 'BFDR': 0.0, 'AvgSpec': 21.33, 'Complex': 'NaN'})
# ('1424', '1416', {'SUID': 2897, 'shared name': 'Nsp15 (interacts with) ARF6', 'shared interaction': 'interacts with', 'name': 'nsp15 (interacts with) ARF6', 'selected': False, 'interaction': 'interacts with', 'Preys': 'P62330', 'MIST': 0.988131492, 'FoldChange': 70.0, 'BFDR': 0.0, 'AvgSpec': 7.0, 'Complex': 'NaN'})
# ('1424', '1420', {'SUID': 2893, 'shared name': 'Nsp15 (interacts with) NUTF2', 'shared interaction': 'interacts with', 'name': 'nsp15 (interacts with) NUTF2', 'selected': False, 'interaction': 'interacts with', 'Preys': 'P61970', 'MIST': 0.987886, 'FoldChange': 23.33, 'BFDR': 0.0, 'AvgSpec': 2.33, 'Complex': 'NaN'})
# ('1408', '1380', {'SUID': 2889, 'shared name': 'Nsp2 (interacts with) GIGYF2', 'shared interaction': 'interacts with', 'name': 'nsp2 (interacts with) GIGYF2', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q6Y7W6', 'MIST': 0.767224555, 'FoldChange': 403.33, 'BFDR': 0.0, 'AvgSpec': 40.33, 'Complex': 'NaN'})
# ('1408', '1384', {'SUID': 2885, 'shared name': 'Nsp2 (interacts with) FKBP15', 'shared interaction': 'interacts with', 'name': 'nsp2 (interacts with) FKBP15', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q5T1M5', 'MIST': 0.988056696, 'FoldChange': 196.67, 'BFDR': 0.0, 'AvgSpec': 19.67, 'Complex': 'NaN'})
# ('1408', '1388', {'SUID': 2881, 'shared name': 'Nsp2 (interacts with) WASHC4', 'shared interaction': 'interacts with', 'name': 'nsp2 (interacts with) WASHC4', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q2M389', 'MIST': 0.972115182, 'FoldChange': 36.67, 'BFDR': 0.0, 'AvgSpec': 3.67, 'Complex': 'NaN'})
# ('1408', '1392', {'SUID': 2877, 'shared name': 'Nsp2 (interacts with) RAP1GDS1', 'shared interaction': 'interacts with', 'name': 'nsp2 (interacts with) RAP1GDS1', 'selected': False, 'interaction': 'interacts with', 'Preys': 'P52306', 'MIST': 0.991635744, 'FoldChange': 120.0, 'BFDR': 0.0, 'AvgSpec': 12.0, 'Complex': 'NaN'})
# ('1408', '1396', {'SUID': 2873, 'shared name': 'Nsp2 (interacts with) POR', 'shared interaction': 'interacts with', 'name': 'nsp2 (interacts with) POR', 'selected': False, 'interaction': 'interacts with', 'Preys': 'P16435', 'MIST': 0.710961769, 'FoldChange': 33.33, 'BFDR': 0.0, 'AvgSpec': 3.33, 'Complex': 'NaN'})
# ('1408', '1400', {'SUID': 2869, 'shared name': 'Nsp2 (interacts with) EIF4E2', 'shared interaction': 'interacts with', 'name': 'nsp2 (interacts with) EIF4E2', 'selected': False, 'interaction': 'interacts with', 'Preys': 'O60573', 'MIST': 0.806833749, 'FoldChange': 103.33, 'BFDR': 0.0, 'AvgSpec': 10.33, 'Complex': 'NaN'})
# ('1408', '1404', {'SUID': 2865, 'shared name': 'Nsp2 (interacts with) SLC27A2', 'shared interaction': 'interacts with', 'name': 'nsp2 (interacts with) SLC27A2', 'selected': False, 'interaction': 'interacts with', 'Preys': 'O14975', 'MIST': 0.915803486, 'FoldChange': 46.67, 'BFDR': 0.0, 'AvgSpec': 4.67, 'Complex': 'NaN'})
# ('1376', '1344', {'SUID': 2861, 'shared name': 'Nsp4 (interacts with) TIMM9', 'shared interaction': 'interacts with', 'name': 'nsp4 (interacts with) TIMM9', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q9Y5J7', 'MIST': 0.913806284, 'FoldChange': 40.0, 'BFDR': 0.0, 'AvgSpec': 4.0, 'Complex': 'NaN'})
# ('1376', '1348', {'SUID': 2857, 'shared name': 'Nsp4 (interacts with) TIMM10B', 'shared interaction': 'interacts with', 'name': 'nsp4 (interacts with) TIMM10B', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q9Y5J6', 'MIST': 0.985104055, 'FoldChange': 30.0, 'BFDR': 0.0, 'AvgSpec': 3.0, 'Complex': 'NaN'})
# ('1376', '1352', {'SUID': 2853, 'shared name': 'Nsp4 (interacts with) DNAJC11', 'shared interaction': 'interacts with', 'name': 'nsp4 (interacts with) DNAJC11', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q9NVH1', 'MIST': 0.726866873, 'FoldChange': 113.33, 'BFDR': 0.0, 'AvgSpec': 11.33, 'Complex': 'NaN'})
# ('1376', '1356', {'SUID': 2849, 'shared name': 'Nsp4 (interacts with) TIMM29', 'shared interaction': 'interacts with', 'name': 'nsp4 (interacts with) TIMM29', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q9BSF4', 'MIST': 0.986980311, 'FoldChange': 76.67, 'BFDR': 0.0, 'AvgSpec': 7.67, 'Complex': 'NaN'})
# ('1376', '1360', {'SUID': 2845, 'shared name': 'Nsp4 (interacts with) NUP210', 'shared interaction': 'interacts with', 'name': 'nsp4 (interacts with) NUP210', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q8TEM1', 'MIST': 0.710174697, 'FoldChange': 63.33, 'BFDR': 0.0, 'AvgSpec': 6.33, 'Complex': 'NaN'})
# ('1376', '1364', {'SUID': 2841, 'shared name': 'Nsp4 (interacts with) ALG11', 'shared interaction': 'interacts with', 'name': 'nsp4 (interacts with) ALG11', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q2TAA5', 'MIST': 0.72745605, 'FoldChange': 70.0, 'BFDR': 0.0, 'AvgSpec': 7.0, 'Complex': 'NaN'})
# ('1376', '1368', {'SUID': 2837, 'shared name': 'Nsp4 (interacts with) TIMM10', 'shared interaction': 'interacts with', 'name': 'nsp4 (interacts with) TIMM10', 'selected': False, 'interaction': 'interacts with', 'Preys': 'P62072', 'MIST': 0.961471982, 'FoldChange': 53.33, 'BFDR': 0.0, 'AvgSpec': 5.33, 'Complex': 'NaN'})
# ('1376', '1372', {'SUID': 2833, 'shared name': 'Nsp4 (interacts with) IDE', 'shared interaction': 'interacts with', 'name': 'nsp4 (interacts with) IDE', 'selected': False, 'interaction': 'interacts with', 'Preys': 'P14735', 'MIST': 0.918031442, 'FoldChange': 113.33, 'BFDR': 0.0, 'AvgSpec': 11.33, 'Complex': 'NaN'})
# ('1368', '1348', {'SUID': 2829, 'shared name': 'TIMM10 (interacts with) TIMM10B', 'shared interaction': 'interacts with', 'name': 'TIMM10 (interacts with) TIMM10B', 'selected': False, 'interaction': 'interacts with'})
# ('1368', '1344', {'SUID': 2825, 'shared name': 'TIMM10 (interacts with) TIMM9', 'shared interaction': 'interacts with', 'name': 'TIMM10 (interacts with) TIMM9', 'selected': False, 'interaction': 'interacts with', 'FoldChange': 0.0, 'BFDR': nan, 'Complex': 'TIM (TIM9, TIM10) complex, mitochondrial'})
# ('1356', '1348', {'SUID': 2821, 'shared name': 'TIMM29 (interacts with) TIMM10B', 'shared interaction': 'interacts with', 'name': 'TIMM29 (interacts with) TIMM10B', 'selected': False, 'interaction': 'interacts with'})
# ('1356', '1344', {'SUID': 2817, 'shared name': 'TIMM29 (interacts with) TIMM9', 'shared interaction': 'interacts with', 'name': 'TIMM29 (interacts with) TIMM9', 'selected': False, 'interaction': 'interacts with'})
# ('1356', '1368', {'SUID': 2813, 'shared name': 'TIMM29 (interacts with) TIMM10', 'shared interaction': 'interacts with', 'name': 'TIMM29 (interacts with) TIMM10', 'selected': False, 'interaction': 'interacts with'})
# ('1344', '1348', {'SUID': 2809, 'shared name': 'TIMM9 (interacts with) TIMM10B', 'shared interaction': 'interacts with', 'name': 'TIMM9 (interacts with) TIMM10B', 'selected': False, 'interaction': 'interacts with'})
# ('1340', '1336', {'SUID': 2805, 'shared name': 'Nsp5 (interacts with) HDAC2', 'shared interaction': 'interacts with', 'name': 'nsp5 (interacts with) HDAC2', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q92769', 'MIST': 0.993708403, 'FoldChange': 20.0, 'BFDR': 0.01, 'AvgSpec': 2.0, 'Complex': 'NaN'})
# ('1332', '1324', {'SUID': 2801, 'shared name': 'Nsp5 C145A (interacts with) TRMT1', 'shared interaction': 'interacts with', 'name': 'nsp5_C145A (interacts with) TRMT1', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q9NXH9', 'MIST': 0.984315505, 'FoldChange': 76.67, 'BFDR': 0.0, 'AvgSpec': 7.67, 'Complex': 'NaN'})
# ('1332', '1328', {'SUID': 2797, 'shared name': 'Nsp5 C145A (interacts with) GPX1', 'shared interaction': 'interacts with', 'name': 'nsp5_C145A (interacts with) GPX1', 'selected': False, 'interaction': 'interacts with', 'Preys': 'P07203', 'MIST': 0.97684084, 'FoldChange': 156.67, 'BFDR': 0.0, 'AvgSpec': 15.67, 'Complex': 'NaN'})
# ('1320', '1304', {'SUID': 2793, 'shared name': 'Nsp6 (interacts with) ATP13A3', 'shared interaction': 'interacts with', 'name': 'nsp6 (interacts with) ATP13A3', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q9H7F0', 'MIST': 0.805525853, 'FoldChange': 56.67, 'BFDR': 0.0, 'AvgSpec': 5.67, 'Complex': 'NaN'})
# ('1320', '1308', {'SUID': 2789, 'shared name': 'Nsp6 (interacts with) SIGMAR1', 'shared interaction': 'interacts with', 'name': 'nsp6 (interacts with) SIGMAR1', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q99720', 'MIST': 0.842213253, 'FoldChange': 50.0, 'BFDR': 0.0, 'AvgSpec': 5.0, 'Complex': 'NaN'})
# ('1320', '1312', {'SUID': 2785, 'shared name': 'Nsp6 (interacts with) ATP6AP1', 'shared interaction': 'interacts with', 'name': 'nsp6 (interacts with) ATP6AP1', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q15904', 'MIST': 0.989106922, 'FoldChange': 50.0, 'BFDR': 0.0, 'AvgSpec': 5.0, 'Complex': 'NaN'})
# ('1320', '1316', {'SUID': 2781, 'shared name': 'Nsp6 (interacts with) ATP5MG', 'shared interaction': 'interacts with', 'name': 'nsp6 (interacts with) ATP5MG', 'selected': False, 'interaction': 'interacts with', 'Preys': 'O75964', 'MIST': 0.717265558, 'FoldChange': 66.67, 'BFDR': 0.0, 'AvgSpec': 6.67, 'Complex': 'NaN'})
# ('1312', '1316', {'SUID': 2777, 'shared name': 'ATP6AP1 (interacts with) ATP5MG', 'shared interaction': 'interacts with', 'name': 'ATP6AP1 (interacts with) ATP5MG', 'selected': False, 'interaction': 'interacts with'})
# ('1304', '1312', {'SUID': 2773, 'shared name': 'ATP13A3 (interacts with) ATP6AP1', 'shared interaction': 'interacts with', 'name': 'ATP13A3 (interacts with) ATP6AP1', 'selected': False, 'interaction': 'interacts with'})
# ('1304', '1316', {'SUID': 2769, 'shared name': 'ATP13A3 (interacts with) ATP5MG', 'shared interaction': 'interacts with', 'name': 'ATP13A3 (interacts with) ATP5MG', 'selected': False, 'interaction': 'interacts with'})
# ('1300', '544', {'SUID': 2765, 'shared name': 'Nsp7 (interacts with) CYB5R3', 'shared interaction': 'interacts with', 'name': 'nsp7 (interacts with) CYB5R3', 'selected': False, 'interaction': 'interacts with', 'Preys': 'P00387', 'MIST': 0.956349351, 'FoldChange': 73.33, 'BFDR': 0.0, 'AvgSpec': 7.33, 'Complex': 'NaN'})
# ('1300', '1176', {'SUID': 2761, 'shared name': 'Nsp7 (interacts with) RAB18', 'shared interaction': 'interacts with', 'name': 'nsp7 (interacts with) RAB18', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q9NP72', 'MIST': 0.756605088, 'FoldChange': 20.0, 'BFDR': 0.05, 'AvgSpec': 2.0, 'Complex': 'NaN'})
# ('1300', '1180', {'SUID': 2757, 'shared name': 'Nsp7 (interacts with) PTGES2', 'shared interaction': 'interacts with', 'name': 'nsp7 (interacts with) PTGES2', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q9H7Z7', 'MIST': 0.764538331, 'FoldChange': 60.0, 'BFDR': 0.0, 'AvgSpec': 6.0, 'Complex': 'NaN'})
# ('1300', '1184', {'SUID': 2753, 'shared name': 'Nsp7 (interacts with) SELENOS', 'shared interaction': 'interacts with', 'name': 'nsp7 (interacts with) SELENOS', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q9BQE4', 'MIST': 0.701764404, 'FoldChange': 33.33, 'BFDR': 0.0, 'AvgSpec': 3.33, 'Complex': 'NaN'})
# ('1300', '1188', {'SUID': 2749, 'shared name': 'Nsp7 (interacts with) DNAJC19', 'shared interaction': 'interacts with', 'name': 'nsp7 (interacts with) DNAJC19', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q96DA6', 'MIST': 0.981450126, 'FoldChange': 30.0, 'BFDR': 0.0, 'AvgSpec': 3.0, 'Complex': 'NaN'})
# ('1300', '1192', {'SUID': 2745, 'shared name': 'Nsp7 (interacts with) FAM162A', 'shared interaction': 'interacts with', 'name': 'nsp7 (interacts with) FAM162A', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q96A26', 'MIST': 0.748773582, 'FoldChange': 110.0, 'BFDR': 0.0, 'AvgSpec': 11.0, 'Complex': 'NaN'})
# ('1300', '1196', {'SUID': 2741, 'shared name': 'Nsp7 (interacts with) DCAKD', 'shared interaction': 'interacts with', 'name': 'nsp7 (interacts with) DCAKD', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q8WVC6', 'MIST': 0.862452335, 'FoldChange': 90.0, 'BFDR': 0.0, 'AvgSpec': 9.0, 'Complex': 'NaN'})
# ('1300', '1200', {'SUID': 2737, 'shared name': 'Nsp7 (interacts with) NAT14', 'shared interaction': 'interacts with', 'name': 'nsp7 (interacts with) NAT14', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q8WUY8', 'MIST': 0.720285746, 'FoldChange': 43.33, 'BFDR': 0.0, 'AvgSpec': 4.33, 'Complex': 'NaN'})
# ('1300', '1204', {'SUID': 2733, 'shared name': 'Nsp7 (interacts with) SCARB1', 'shared interaction': 'interacts with', 'name': 'nsp7 (interacts with) SCARB1', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q8WTV0', 'MIST': 0.854406247, 'FoldChange': 26.67, 'BFDR': 0.03, 'AvgSpec': 2.67, 'Complex': 'NaN'})
# ('1300', '1208', {'SUID': 2729, 'shared name': 'Nsp7 (interacts with) SCCPDH', 'shared interaction': 'interacts with', 'name': 'nsp7 (interacts with) SCCPDH', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q8NBX0', 'MIST': 0.978675119, 'FoldChange': 23.33, 'BFDR': 0.0, 'AvgSpec': 2.33, 'Complex': 'NaN'})
# ('1300', '1212', {'SUID': 2725, 'shared name': 'Nsp7 (interacts with) NDUFAF2', 'shared interaction': 'interacts with', 'name': 'nsp7 (interacts with) NDUFAF2', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q8N183', 'MIST': 0.981444858, 'FoldChange': 30.0, 'BFDR': 0.0, 'AvgSpec': 3.0, 'Complex': 'NaN'})
# ('1300', '1216', {'SUID': 2721, 'shared name': 'Nsp7 (interacts with) HS2ST1', 'shared interaction': 'interacts with', 'name': 'nsp7 (interacts with) HS2ST1', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q7LGA3', 'MIST': 0.706466834, 'FoldChange': 50.0, 'BFDR': 0.0, 'AvgSpec': 5.0, 'Complex': 'NaN'})
# ('1300', '1220', {'SUID': 2717, 'shared name': 'Nsp7 (interacts with) QSOX2', 'shared interaction': 'interacts with', 'name': 'nsp7 (interacts with) QSOX2', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q6ZRP7', 'MIST': 0.794325146, 'FoldChange': 43.33, 'BFDR': 0.03, 'AvgSpec': 4.33, 'Complex': 'NaN'})
# ('1300', '1224', {'SUID': 2713, 'shared name': 'Nsp7 (interacts with) MTARC1', 'shared interaction': 'interacts with', 'name': 'nsp7 (interacts with) MTARC1', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q5VT66', 'MIST': 0.939721024, 'FoldChange': 63.33, 'BFDR': 0.0, 'AvgSpec': 6.33, 'Complex': 'NaN'})
# ('1300', '1228', {'SUID': 2709, 'shared name': 'Nsp7 (interacts with) TOR1AIP1', 'shared interaction': 'interacts with', 'name': 'nsp7 (interacts with) TOR1AIP1', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q5JTV8', 'MIST': 0.74516805, 'FoldChange': 20.0, 'BFDR': 0.05, 'AvgSpec': 2.0, 'Complex': 'NaN'})
# ('1300', '1232', {'SUID': 2705, 'shared name': 'Nsp7 (interacts with) MOGS', 'shared interaction': 'interacts with', 'name': 'nsp7 (interacts with) MOGS', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q13724', 'MIST': 0.782330987, 'FoldChange': 276.67, 'BFDR': 0.0, 'AvgSpec': 27.67, 'Complex': 'NaN'})
# ('1300', '1236', {'SUID': 2701, 'shared name': 'Nsp7 (interacts with) LMAN2', 'shared interaction': 'interacts with', 'name': 'nsp7 (interacts with) LMAN2', 'selected': False, 'interaction': 'interacts with', 'Preys': 'Q12907', 'MIST': 0.725773983, 'FoldChange': 70.0, 'BFDR': 0.0, 'AvgSpec': 7.0, 'Complex': 'NaN'})
# ('1300', '1240', {'SUID': 2697, 'shared name': 'Nsp7 (interacts with) GNG5', 'shared interaction': 'interacts with', 'name': 'nsp7 (interacts with) GNG5', 'selected': False, 'interaction': 'interacts with', 'Preys': 'P63218', 'MIST': 0.817631566, 'FoldChange': 20.0, 'BFDR': 0.05, 'AvgSpec': 2.0, 'Complex': 'NaN'})
# ('1300', '1244', {'SUID': 2693, 'shared name': 'Nsp7 (interacts with) GNB1', 'shared interaction': 'interacts with', 'name': 'nsp7 (interacts with) GNB1', 'selected': False, 'interaction': 'interacts with', 'Preys': 'P62873', 'MIST': 0.839532136, 'FoldChange': 26.67, 'BFDR': 0.0, 'AvgSpec': 2.67, 'Complex': 'NaN'})
# ('1300', '1248', {'SUID': 2689, 'shared name': 'Nsp7 (interacts with) RAB1A', 'shared interaction': 'interacts with', 'name': 'nsp7 (interacts with) RAB1A', 'selected': False, 'interaction': 'interacts with', 'Preys': 'P62820', 'MIST': 0.935289593, 'FoldChange': 40.0, 'BFDR': 0.0, 'AvgSpec': 4.0, 'Complex': 'NaN'})
# ('1300', '1252', {'SUID': 2685, 'shared name': 'Nsp7 (interacts with) RHOA', 'shared interaction': 'interacts with', 'name': 'nsp7 (interacts with) RHOA', 'selected': False, 'interaction': 'interacts with', 'Preys': 'P61586', 'MIST': 0.829029399, 'FoldChange': 20.0, 'BFDR': 0.05, 'AvgSpec': 2.0, 'Complex': 'NaN'})
# ('1300', '1256', {'SUID': 2681, 'shared name': 'Nsp7 (interacts with) RAB14', 'shared interaction': 'interacts with', 'name': 'nsp7 (interacts with) RAB14', 'selected': False, 'interaction': 'interacts with', 'Preys': 'P61106', 'MIST': 0.750712826, 'FoldChange': 66.67, 'BFDR': 0.0, 'AvgSpec': 6.67, 'Complex': 'NaN'})
# ...
# ('Nsp13', 'NINL', {})
# ('Nsp13', 'HOOK1', {})
# ('Nsp13', 'TBK1', {})
# ('Nsp13', 'CEP250', {})
# ('Nsp13', 'C1orf50', {})
# ('Nsp13', 'FYCO1', {})
# ('Nsp13', 'GORASP1', {})
# ('Nsp13', 'AKAP9', {})
# ('Nsp13', 'CDK5RAP2', {})
# ('Nsp13', 'JAKMIP1', {})
# ('Nsp13', 'GCC1', {})
# ('Nsp13', 'USP13', {})
# ('Nsp13', 'MIPOL1', {})
# ('Nsp13', 'CEP112', {})
# ('Nsp13', 'NIN', {})
# ('Nsp13', 'CLIP4', {})
# ('Nsp13', 'GCC2', {})
# ('Nsp13', 'ERC1', {})
# ('Nsp13', 'CNTRL', {})
# ('Nsp13', 'CEP68', {})
# ('Nsp13', 'CEP135', {})
# ('Nsp13', 'PDE4DIP', {})
# ('Nsp13', 'CEP350', {})
# ('Nsp13', 'GRIPAP1', {})
# ('Nsp13', 'GOLGB1', {})
# ('Nsp13', 'GOLGA2', {})
# ('Nsp13', 'GOLGA3', {})
# ('Nsp13', 'TLE5', {})
# ('Nsp13', 'TLE3', {})
# ('Nsp13', 'TLE1', {})
# ('Nsp13', 'CENPF', {})
# ('Nsp13', 'RDX', {})
# ('Nsp13', 'PRKAR2B', {})
# ('Nsp13', 'PRKACA', {})
# ('Nsp13', 'PRKAR2A', {})
# ('Nsp13', 'CEP43', {})
# ('Nsp13', 'PCNT', {})
# ('Nsp13', 'HSBP1', {})
# ('Nsp13', 'CIT', {})
# ('Nsp13', 'TBKBP1', {})
# ('NINL', 'CEP43', {})
# ('NINL', 'CENPF', {})
# ('NINL', 'CDK5RAP2', {})
# ('NINL', 'PCNT', {})
# ('NINL', 'NIN', {})
# ('NINL', 'CEP350', {})
# ('NINL', 'CEP135', {})
# ('NINL', 'CNTRL', {})
# ('NINL', 'CEP250', {})
# ('NINL', 'CEP68', {})
# ('NINL', 'CEP112', {})
# ('TBK1', 'TBKBP1', {})
# ('CEP250', 'PCNT', {})
# ('CEP250', 'CEP43', {})
# ('CEP250', 'CENPF', {})
# ('CEP250', 'CEP135', {})
# ('CEP250', 'CEP68', {})
# ('CEP250', 'CNTRL', {})
# ('CEP250', 'NIN', {})
# ('CEP250', 'CDK5RAP2', {})
# ('CEP250', 'CEP350', {})
# ('CEP250', 'CEP112', {})
# ('AKAP9', 'PRKAR2B', {})
# ('AKAP9', 'PRKAR2A', {})
# ('AKAP9', 'PRKACA', {})
# ('CDK5RAP2', 'CEP43', {})
# ('CDK5RAP2', 'CENPF', {})
# ('CDK5RAP2', 'PCNT', {})
# ('CDK5RAP2', 'NIN', {})
# ('CDK5RAP2', 'CEP350', {})
# ('CDK5RAP2', 'CEP135', {})
# ('CDK5RAP2', 'CNTRL', {})
# ('CDK5RAP2', 'CEP68', {})
# ('CDK5RAP2', 'CEP112', {})
# ('CEP112', 'PCNT', {})
# ('CEP112', 'CEP43', {})
# ('CEP112', 'CENPF', {})
# ('CEP112', 'CEP350', {})
# ('CEP112', 'CEP135', {})
# ('CEP112', 'CEP68', {})
# ('CEP112', 'CNTRL', {})
# ('CEP112', 'NIN', {})
# ('NIN', 'PCNT', {})
# ('NIN', 'CEP43', {})
# ('NIN', 'CENPF', {})
# ('NIN', 'CEP350', {})
# ('NIN', 'CEP135', {})
# ('NIN', 'CNTRL', {})
# ('NIN', 'CEP68', {})
# ('CNTRL', 'PCNT', {})
# ('CNTRL', 'CEP43', {})
# ('CNTRL', 'CENPF', {})
# ('CNTRL', 'CEP350', {})
# ('CNTRL', 'CEP135', {})
# ('CNTRL', 'CEP68', {})
# ('CEP68', 'PCNT', {})
# ('CEP68', 'CEP43', {})
# ('CEP68', 'CENPF', {})
# ('CEP68', 'CEP135', {})
# ('CEP68', 'CEP350', {})
# ('CEP135', 'PCNT', {})
# ('CEP135', 'CEP43', {})
# ('CEP135', 'CENPF', {})
# ('CEP135', 'CEP350', {})
# ('CEP350', 'PCNT', {})
# ('CEP350', 'CEP43', {})
# ('CEP350', 'CENPF', {})
# ('TLE5', 'TLE1', {})
# ('TLE5', 'TLE3', {})
# ('TLE3', 'TLE1', {})
# ('CENPF', 'CEP43', {})
# ('CENPF', 'PCNT', {})
# ('PRKAR2B', 'PRKAR2A', {})
# ('PRKACA', 'PRKAR2A', {})
# ('CEP43', 'PCNT', {})
# ('Nsp14', 'SIRT5', {})
# ('Nsp14', 'IMPDH2', {})
# ('Nsp14', 'GLA', {})
# ('Nsp15', 'RNF41', {})
# ('Nsp15', 'ARF6', {})
# ('Nsp15', 'NUTF2', {})
# ('Nsp2', 'GIGYF2', {})
# ('Nsp2', 'FKBP15', {})
# ('Nsp2', 'WASHC4', {})
# ('Nsp2', 'RAP1GDS1', {})
# ('Nsp2', 'POR', {})
# ('Nsp2', 'EIF4E2', {})
# ('Nsp2', 'SLC27A2', {})
# ('Nsp4', 'TIMM9', {})
# ('Nsp4', 'TIMM10B', {})
# ('Nsp4', 'DNAJC11', {})
# ('Nsp4', 'TIMM29', {})
# ('Nsp4', 'NUP210', {})
# ('Nsp4', 'ALG11', {})
# ('Nsp4', 'TIMM10', {})
# ('Nsp4', 'IDE', {})
# ('TIMM9', 'TIMM10', {})
# ('TIMM9', 'TIMM29', {})
# ('TIMM9', 'TIMM10B', {})
# ('TIMM10B', 'TIMM10', {})
# ('TIMM10B', 'TIMM29', {})
# ('TIMM29', 'TIMM10', {})
# ('Nsp5', 'HDAC2', {})
# ('Nsp5 C145A', 'TRMT1', {})
# ('Nsp5 C145A', 'GPX1', {})
# ('Nsp6', 'ATP13A3', {})
# ('Nsp6', 'SIGMAR1', {})
# ('Nsp6', 'ATP6AP1', {})
# ('Nsp6', 'ATP5MG', {})
# ('ATP13A3', 'ATP6AP1', {})
# ('ATP13A3', 'ATP5MG', {})
# ('ATP6AP1', 'ATP5MG', {})
# ('Nsp7', 'CYB5R3', {})
# ('Nsp7', 'RAB18', {})
# ('Nsp7', 'PTGES2', {})
# ('Nsp7', 'SELENOS', {})
# ('Nsp7', 'DNAJC19', {})
# ('Nsp7', 'FAM162A', {})
# ('Nsp7', 'DCAKD', {})
# ('Nsp7', 'NAT14', {})
# ('Nsp7', 'SCARB1', {})
# ('Nsp7', 'SCCPDH', {})
# ('Nsp7', 'NDUFAF2', {})
# ('Nsp7', 'HS2ST1', {})
# ('Nsp7', 'QSOX2', {})
# ('Nsp7', 'MTARC1', {})
# ('Nsp7', 'TOR1AIP1', {})
# ('Nsp7', 'MOGS', {})
# ('Nsp7', 'LMAN2', {})
# ('Nsp7', 'GNG5', {})
# ('Nsp7', 'GNB1', {})
# ('Nsp7', 'RAB1A', {})
# ('Nsp7', 'RHOA', {})
# ('Nsp7', 'RAB14', {})
# ('Nsp7', 'RAB10', {})
# ('Nsp7', 'RAB2A', {})
# ('Nsp7', 'RAB8A', {})
# ('Nsp7', 'RAB7A', {})
# ('Nsp7', 'RAB5C', {})
# ('Nsp7', 'COMT', {})
# ('Nsp7', 'RALA', {})
# ('Nsp7', 'ACSL3', {})
# ('Nsp7', 'CYB5B', {})
# ('Nsp7', 'AGPS', {})
# ('GNG5', 'GNB1', {})
# ('Nsp8', 'MRPS27', {})
# ('Nsp8', 'EXOSC2', {})
# ('Nsp8', 'MRPS5', {})
# ('Nsp8', 'MRPS2', {})
# ('Nsp8', 'HECTD1', {})
# ('Nsp8', 'AATF', {})
# ('Nsp8', 'EXOSC3', {})
# ('Nsp8', 'EXOSC5', {})
# ('Nsp8', 'SEPSECS', {})
# ('Nsp8', 'CCDC86', {})
# ('Nsp8', 'NOL10', {})
# ('Nsp8', 'NARS2', {})
# ('Nsp8', 'EXOSC8', {})
# ('Nsp8', 'NGDN', {})
# ('Nsp8', 'MEPCE', {})
# ('Nsp8', 'LARP7', {})
# ('Nsp8', 'DDX10', {})
# ('Nsp8', 'MRPS25', {})
# ('Nsp8', 'SRP54', {})
# ('Nsp8', 'SRP19', {})
# ('Nsp8', 'NSD2', {})
# ('Nsp8', 'ATE1', {})
# ('Nsp8', 'SRP72', {})
# ('Nsp8', 'MPHOSPH10', {})
# ('MRPS27', 'MRPS25', {})
# ('MRPS27', 'MRPS2', {})
# ('MRPS27', 'MRPS5', {})
# ('EXOSC2', 'EXOSC8', {})
# ('EXOSC2', 'EXOSC5', {})
# ('EXOSC2', 'EXOSC3', {})
# ('MRPS5', 'MRPS25', {})
# ('MRPS5', 'MRPS2', {})
# ('MRPS2', 'MRPS25', {})
# ('AATF', 'NOL10', {})
# ('AATF', 'NGDN', {})
# ('EXOSC3', 'EXOSC8', {})
# ('EXOSC3', 'EXOSC5', {})
# ('EXOSC5', 'EXOSC8', {})
# ('NOL10', 'NGDN', {})
# ('MEPCE', 'LARP7', {})
# ('SRP54', 'SRP72', {})
# ('SRP54', 'SRP19', {})
# ('SRP19', 'SRP72', {})
# ('Nsp9', 'FBLN5', {})
# ('Nsp9', 'MAT2B', {})
# ('Nsp9', 'NUP58', {})
# ('Nsp9', 'NUP88', {})
# ('Nsp9', 'ZNF503', {})
# ('Nsp9', 'NEK9', {})
# ('Nsp9', 'SPART', {})
# ('Nsp9', 'MIB1', {})
# ('Nsp9', 'NUP54', {})
# ('Nsp9', 'EIF4H', {})
# ('Nsp9', 'DCAF7', {})
# ('Nsp9', 'NUP62', {})
# ('Nsp9', 'NUP214', {})
# ('Nsp9', 'FBN2', {})
# ('Nsp9', 'FBN1', {})
# ('Nsp9', 'GTF2F2', {})
# ('FBLN5', 'FBN2', {})
# ('FBLN5', 'FBN1', {})
# ('NUP58', 'NUP214', {})
# ('NUP58', 'NUP54', {})
# ('NUP58', 'NUP88', {})
# ('NUP58', 'NUP62', {})
# ('NUP88', 'NUP214', {})
# ('NUP88', 'NUP62', {})
# ('NUP88', 'NUP54', {})
# ('NUP54', 'NUP214', {})
# ('NUP54', 'NUP62', {})
# ('NUP62', 'NUP214', {})
# ('FBN2', 'FBN1', {})
# ('Orf10', 'ELOB', {})
# ('Orf10', 'ELOC', {})
# ('Orf10', 'RBX1', {})
# ('Orf10', 'TIMM8B', {})
# ('Orf10', 'ZYG11B', {})
# ('Orf10', 'THTPA', {})
# ('Orf10', 'MAP7D1', {})
# ('Orf10', 'CUL2', {})
# ('Orf10', 'PPT1', {})
# ('ELOB', 'CUL2', {})
# ('ELOB', 'RBX1', {})
# ('ELOB', 'ZYG11B', {})
# ('ELOB', 'ELOC', {})
# ('ELOC', 'CUL2', {})
# ('ELOC', 'RBX1', {})
# ('ELOC', 'ZYG11B', {})
# ('RBX1', 'CUL2', {})
# ('RBX1', 'ZYG11B', {})
# ('ZYG11B', 'CUL2', {})
# ('Orf3a', 'ALG5', {})
# ('Orf3a', 'SUN2', {})
# ('Orf3a', 'VPS11', {})
# ('Orf3a', 'CLCC1', {})
# ('Orf3a', 'VPS39', {})
# ('Orf3a', 'ARL6IP6', {})
# ('Orf3a', 'TRIM59', {})
# ('Orf3a', 'HMOX1', {})
# ('VPS11', 'VPS39', {})
# ('Orf3b', 'STOML2', {})
# ('Orf6', 'MTCH1', {})
# ('Orf6', 'RAE1', {})
# ('Orf6', 'NUP98', {})
# ('RAE1', 'NUP98', {})
# ('Orf7a', 'MDN1', {})
# ('Orf7a', 'HEATR3', {})
# ('Orf8', 'FKBP10', {})
# ('Orf8', 'ADAM9', {})
# ('Orf8', 'FKBP7', {})
# ('Orf8', 'HYOU1', {})
# ('Orf8', 'ADAMTS1', {})
# ('Orf8', 'CHPF2', {})
# ('Orf8', 'UGGT2', {})
# ('Orf8', 'FBXL12', {})
# ('Orf8', 'PLEKHF2', {})
# ('Orf8', 'SMOC1', {})
# ('Orf8', 'POFUT1', {})
# ('Orf8', 'SIL1', {})
# ('Orf8', 'EDEM3', {})
# ('Orf8', 'ERP44', {})
# ('Orf8', 'TM2D3', {})
# ('Orf8', 'GDF15', {})
# ('Orf8', 'NEU1', {})
# ('Orf8', 'SDF2', {})
# ('Orf8', 'HS6ST2', {})
# ('Orf8', 'NGLY1', {})
# ('Orf8', 'IL17RA', {})
# ('Orf8', 'ERLEC1', {})
# ('Orf8', 'GGH', {})
# ('Orf8', 'EMC1', {})
# ('Orf8', 'PUSL1', {})
# ('Orf8', 'CHPF', {})
# ('Orf8', 'FOXRED2', {})
# ('Orf8', 'PLD3', {})
# ('Orf8', 'ERO1B', {})
# ('Orf8', 'POGLUT3', {})
# ('Orf8', 'POGLUT2', {})
# ('Orf8', 'NPTX1', {})
# ('Orf8', 'OS9', {})
# ('Orf8', 'MFGE8', {})
# ('Orf8', 'NPC2', {})
# ('Orf8', 'INHBE', {})
# ('Orf8', 'PCSK6', {})
# ('Orf8', 'LOX', {})
# ('Orf8', 'DNMT1', {})
# ('Orf8', 'PVR', {})
# ('Orf8', 'COL6A1', {})
# ('Orf8', 'CISD3', {})
# ('Orf8', 'ITGB1', {})
# ('Orf8', 'PLAT', {})
# ('Orf8', 'STC2', {})
# ('Orf8', 'TOR1A', {})
# ('Orf8', 'PLOD2', {})
# ('FKBP10', 'PLOD2', {})
# ('ADAM9', 'ITGB1', {})
# ('Orf9b', 'BAG5', {})
# ('Orf9b', 'PTBP2', {})
# ('Orf9b', 'MARK1', {})
# ('Orf9b', 'DCTPP1', {})
# ('Orf9b', 'DPH5', {})
# ('Orf9b', 'MARK2', {})
# ('Orf9b', 'MARK3', {})
# ('Orf9b', 'TOMM70', {})
# ('Orf9b', 'CSDE1', {})
# ('Orf9b', 'CHMP2A', {})
# ('Orf9b', 'SLC9A3R1', {})
# ('Orf9c', 'PIGS', {})
# ('Orf9c', 'NDUFB9', {})
# ('Orf9c', 'TMED5', {})
# ('Orf9c', 'NDUFAF1', {})
# ('Orf9c', 'BCS1L', {})
# ('Orf9c', 'NDFIP2', {})
# ('Orf9c', 'ACAD9', {})
# ('Orf9c', 'GHITM', {})
# ('Orf9c', 'TMEM39B', {})
# ('Orf9c', 'ALG8', {})
# ('Orf9c', 'ECSIT', {})
# ('Orf9c', 'FAR2', {})
# ('Orf9c', 'PIGO', {})
# ('Orf9c', 'RETREG3', {})
# ('Orf9c', 'NLRX1', {})
# ('Orf9c', 'ERMP1', {})
# ('Orf9c', 'TAPT1', {})
# ('Orf9c', 'SLC30A6', {})
# ('Orf9c', 'TMEM97', {})
# ('Orf9c', 'DPY19L1', {})
# ('Orf9c', 'SCAP', {})
# ('Orf9c', 'F2RL1', {})
# ('Orf9c', 'ABCC1', {})
# ('Orf9c', 'WFS1', {})
# ('Orf9c', 'GPAA1', {})
# ('Orf9c', 'UBXN8', {})
# ('PIGS', 'GPAA1', {})
# ('NDUFAF1', 'ECSIT', {})
# ('E', 'SLC44A2', {})
# ('E', 'ZC3H18', {})
# ('E', 'CWC27', {})
# ('E', 'BRD2', {})
# ('E', 'BRD4', {})
# ('E', 'AP3B1', {})
# ('M', 'BZW2', {})
# ('M', 'AAR2', {})
# ('M', 'AKAP8L', {})
# ('M', 'AASS', {})
# ('M', 'FAM8A1', {})
# ('M', 'RTN4', {})
# ('M', 'TARS2', {})
# ('M', 'TUBGCP2', {})
# ('M', 'SLC25A21', {})
# ('M', 'INTS4', {})
# ('M', 'REEP6', {})
# ('M', 'SAAL1', {})
# ('M', 'COQ8B', {})
# ('M', 'TUBGCP3', {})
# ('M', 'SLC30A7', {})
# ('M', 'FASTKD5', {})
# ('M', 'SLC30A9', {})
# ('M', 'PITRM1', {})
# ('M', 'ANO6', {})
# ('M', 'PMPCA', {})
# ('M', 'REEP5', {})
# ('M', 'PSMD8', {})
# ('M', 'ATP6V1A', {})
# ('M', 'GGCX', {})
# ('M', 'STOM', {})
# ('M', 'ETFA', {})
# ('M', 'ACADM', {})
# ('M', 'ATP1B1', {})
# ('M', 'YIF1A', {})
# ('M', 'PMPCB', {})
# ('TUBGCP2', 'TUBGCP3', {})
# ('N', 'FAM98A', {})
# ('N', 'LARP1', {})
# ('N', 'PABPC4', {})
# ('N', 'G3BP1', {})
# ('N', 'CSNK2B', {})
# ('N', 'CSNK2A2', {})
# ('N', 'PABPC1', {})
# ('N', 'RRP9', {})
# ('N', 'RPL36', {})
# ('N', 'RBM28', {})
# ('N', 'DDX21', {})
# ('N', 'G3BP2', {})
# ('N', 'MOV10', {})
# ('N', 'UPF1', {})
# ('N', 'SNIP1', {})
# ('LARP1', 'PABPC1', {})
# ('PABPC1', 'MOV10', {})
# ('RPL36', 'MOV10', {})
# ('RPL36', 'DDX21', {})
# ('RPL36', 'RBM28', {})
# ('RBM28', 'DDX21', {})
# ('Spike', 'ZDHHC5', {})
# ('Spike', 'GOLGA7', {})
# ('ZDHHC5', 'GOLGA7', {})
# ('Nsp1', 'PKP2', {})
# ('Nsp1', 'COLGALT1', {})
# ('Nsp1', 'POLA2', {})
# ('Nsp1', 'PRIM2', {})
# ('Nsp1', 'PRIM1', {})
# ('Nsp1', 'POLA1', {})
# ('POLA2', 'POLA1', {})
# ('POLA2', 'PRIM2', {})
# ('POLA2', 'PRIM1', {})
# ('PRIM2', 'POLA1', {})
# ('PRIM2', 'PRIM1', {})
# ('PRIM1', 'POLA1', {})
# ('Nsp10', 'GRPEL1', {})
# ('Nsp10', 'AP2M1', {})
# ('Nsp10', 'ERGIC1', {})
# ('Nsp10', 'GFER', {})
# ('Nsp10', 'AP2A2', {})
# ('AP2M1', 'AP2A2', {})
# ('Nsp11', 'TBCA', {})
# ('Nsp12', 'PLEKHA5', {})
# ('Nsp12', 'PPIL3', {})
# ('Nsp12', 'TCF12', {})
# ('Nsp12', 'RBM41', {})
# ('Nsp12', 'LARP4B', {})
# ('Nsp12', 'ZC3H7A', {})
# ('Nsp12', 'USP54', {})
# ('Nsp12', 'CRTC3', {})
# ('Nsp12', 'ZNF318', {})
# ('Nsp12', 'UBAP2', {})
# ('Nsp12', 'PRRC2B', {})
# ('Nsp12', 'PDZD11', {})
# ('Nsp12', 'TYSND1', {})
# ('Nsp12', 'UBAP2L', {})
# ('Nsp12', 'RIPK1', {})
# ('Nsp12', 'SLU7', {})
# ('Nsp12', 'MYCBP2', {})
# ('Nsp12', 'AKAP8', {})
# ('Nsp12', 'BCKDK', {})
# ('Nsp13', {})
# ('NINL', {})
# ('HOOK1', {})
# ('TBK1', {})
# ('CEP250', {})
# ('C1orf50', {})
# ('FYCO1', {})
# ('GORASP1', {})
# ('AKAP9', {})
# ('CDK5RAP2', {})
# ('JAKMIP1', {})
# ('GCC1', {})
# ('USP13', {})
# ('MIPOL1', {})
# ('CEP112', {})
# ('NIN', {})
# ('CLIP4', {})
# ('GCC2', {})
# ('ERC1', {})
# ('CNTRL', {})
# ('CEP68', {})
# ('CEP135', {})
# ('PDE4DIP', {})
# ('CEP350', {})
# ('GRIPAP1', {})
# ('GOLGB1', {})
# ('GOLGA2', {})
# ('GOLGA3', {})
# ('TLE5', {})
# ('TLE3', {})
# ('TLE1', {})
# ('CENPF', {})
# ('RDX', {})
# ('PRKAR2B', {})
# ('PRKACA', {})
# ('PRKAR2A', {})
# ('CEP43', {})
# ('PCNT', {})
# ('HSBP1', {})
# ('CIT', {})
# ('TBKBP1', {})
# ('Nsp14', {})
# ('SIRT5', {})
# ('IMPDH2', {})
# ('GLA', {})
# ('Nsp15', {})
# ('RNF41', {})
# ('ARF6', {})
# ('NUTF2', {})
# ('Nsp2', {})
# ('GIGYF2', {})
# ('FKBP15', {})
# ('WASHC4', {})
# ('RAP1GDS1', {})
# ('POR', {})
# ('EIF4E2', {})
# ('SLC27A2', {})
# ('Nsp4', {})
# ('TIMM9', {})
# ('TIMM10B', {})
# ('DNAJC11', {})
# ('TIMM29', {})
# ('NUP210', {})
# ('ALG11', {})
# ('TIMM10', {})
# ('IDE', {})
# ('Nsp5', {})
# ('HDAC2', {})
# ('Nsp5 C145A', {})
# ('TRMT1', {})
# ('GPX1', {})
# ('Nsp6', {})
# ('ATP13A3', {})
# ('SIGMAR1', {})
# ('ATP6AP1', {})
# ('ATP5MG', {})
# ('Nsp7', {})
# ('CYB5R3', {})
# ('RAB18', {})
# ('PTGES2', {})
# ('SELENOS', {})
# ('DNAJC19', {})
# ('FAM162A', {})
# ('DCAKD', {})
# ('NAT14', {})
# ('SCARB1', {})
# ('SCCPDH', {})
# ('NDUFAF2', {})
# ('HS2ST1', {})
# ('QSOX2', {})
# ('MTARC1', {})
# ('TOR1AIP1', {})
# ('MOGS', {})
# ('LMAN2', {})
# ('GNG5', {})
# ('GNB1', {})
# ('RAB1A', {})
# ('RHOA', {})
# ('RAB14', {})
# ('RAB10', {})
# ('RAB2A', {})
# ('RAB8A', {})
# ('RAB7A', {})
# ('RAB5C', {})
# ('COMT', {})
# ('RALA', {})
# ('ACSL3', {})
# ('CYB5B', {})
# ('AGPS', {})
# ('Nsp8', {})
# ('MRPS27', {})
# ('EXOSC2', {})
# ('MRPS5', {})
# ('MRPS2', {})
# ('HECTD1', {})
# ('AATF', {})
# ('EXOSC3', {})
# ('EXOSC5', {})
# ('SEPSECS', {})
# ('CCDC86', {})
# ('NOL10', {})
# ('NARS2', {})
# ('EXOSC8', {})
# ('NGDN', {})
# ('MEPCE', {})
# ('LARP7', {})
# ('DDX10', {})
# ('MRPS25', {})
# ('SRP54', {})
# ('SRP19', {})
# ('NSD2', {})
# ('ATE1', {})
# ('SRP72', {})
# ('MPHOSPH10', {})
# ('Nsp9', {})
# ('FBLN5', {})
# ('MAT2B', {})
# ('NUP58', {})
# ('NUP88', {})
# ('ZNF503', {})
# ('NEK9', {})
# ('SPART', {})
# ('MIB1', {})
# ('NUP54', {})
# ('EIF4H', {})
# ('DCAF7', {})
# ('NUP62', {})
# ('NUP214', {})
# ('FBN2', {})
# ('FBN1', {})
# ('GTF2F2', {})
# ('Orf10', {})
# ('ELOB', {})
# ('ELOC', {})
# ('RBX1', {})
# ('TIMM8B', {})
# ('ZYG11B', {})
# ('THTPA', {})
# ('MAP7D1', {})
# ('CUL2', {})
# ('PPT1', {})
# ('Orf3a', {})
# ('ALG5', {})
# ('SUN2', {})
# ('VPS11', {})
# ('CLCC1', {})
# ('VPS39', {})
# ('ARL6IP6', {})
# ('TRIM59', {})
# ('HMOX1', {})
# ('Orf3b', {})
# ('STOML2', {})
# ('Orf6', {})
# ('MTCH1', {})
# ('RAE1', {})
# ('NUP98', {})
# ('Orf7a', {})
# ('MDN1', {})
# ('HEATR3', {})
# ('Orf8', {})
# ('FKBP10', {})
# ('ADAM9', {})
# ('FKBP7', {})
# ('HYOU1', {})
# ('ADAMTS1', {})
# ('CHPF2', {})
# ('UGGT2', {})
# ('FBXL12', {})
# ('PLEKHF2', {})
# ('SMOC1', {})
# ('POFUT1', {})
# ('SIL1', {})
# ('EDEM3', {})
# ('ERP44', {})
# ('TM2D3', {})
# ('GDF15', {})
# ('NEU1', {})
# ('SDF2', {})
# ('HS6ST2', {})
# ('NGLY1', {})
# ('IL17RA', {})
# ('ERLEC1', {})
# ('GGH', {})
# ('EMC1', {})
# ('PUSL1', {})
# ('CHPF', {})
# ('FOXRED2', {})
# ('PLD3', {})
# ('ERO1B', {})
# ('POGLUT3', {})
# ('POGLUT2', {})
# ('NPTX1', {})
# ('OS9', {})
# ('MFGE8', {})
# ('NPC2', {})
# ('INHBE', {})
# ('PCSK6', {})
# ('LOX', {})
# ('DNMT1', {})
# ('PVR', {})
# ('COL6A1', {})
# ('CISD3', {})
# ('ITGB1', {})
# ('PLAT', {})
# ('STC2', {})
# ('TOR1A', {})
# ('PLOD2', {})
# ('Orf9b', {})
# ('BAG5', {})
# ('PTBP2', {})
# ('MARK1', {})
# ('DCTPP1', {})
# ('DPH5', {})
# ('MARK2', {})
# ('MARK3', {})
# ('TOMM70', {})
# ('CSDE1', {})
# ('CHMP2A', {})
# ('SLC9A3R1', {})
# ('Orf9c', {})
# ('PIGS', {})
# ('NDUFB9', {})
# ('TMED5', {})
# ('NDUFAF1', {})
# ('BCS1L', {})
# ('NDFIP2', {})
# ('ACAD9', {})
# ('GHITM', {})
# ('TMEM39B', {})
# ('ALG8', {})
# ('ECSIT', {})
# ('FAR2', {})
# ('PIGO', {})
# ('RETREG3', {})
# ('NLRX1', {})
# ('ERMP1', {})
# ('TAPT1', {})
# ('SLC30A6', {})
# ('TMEM97', {})
# ('DPY19L1', {})
# ('SCAP', {})
# ('F2RL1', {})
# ('ABCC1', {})
# ('WFS1', {})
# ('GPAA1', {})
# ('UBXN8', {})
# ('E', {})
# ('SLC44A2', {})
# ('ZC3H18', {})
# ('CWC27', {})
# ('BRD2', {})
# ('BRD4', {})
# ('AP3B1', {})
# ('M', {})
# ('BZW2', {})
# ('AAR2', {})
# ('AKAP8L', {})
# ('AASS', {})
# ('FAM8A1', {})
# ('RTN4', {})
# ('TARS2', {})
# ('TUBGCP2', {})
# ('SLC25A21', {})
# ('INTS4', {})
# ('REEP6', {})
# ('SAAL1', {})
# ('COQ8B', {})
# ('TUBGCP3', {})
# ('SLC30A7', {})
# ('FASTKD5', {})
# ('SLC30A9', {})
# ('PITRM1', {})
# ('ANO6', {})
# ('PMPCA', {})
# ('REEP5', {})
# ('PSMD8', {})
# ('ATP6V1A', {})
# ('GGCX', {})
# ('STOM', {})
# ('ETFA', {})
# ('ACADM', {})
# ('ATP1B1', {})
# ('YIF1A', {})
# ('PMPCB', {})
# ('N', {})
# ('FAM98A', {})
# ('LARP1', {})
# ('PABPC4', {})
# ('G3BP1', {})
# ('CSNK2B', {})
# ('CSNK2A2', {})
# ('PABPC1', {})
# ('RRP9', {})
# ('RPL36', {})
# ('RBM28', {})
# ('DDX21', {})
# ('G3BP2', {})
# ('MOV10', {})
# ('UPF1', {})
# ('SNIP1', {})
# ('Spike', {})
# ('ZDHHC5', {})
# ('GOLGA7', {})
# ('Nsp1', {})
# ('PKP2', {})
# ('COLGALT1', {})
# ('POLA2', {})
# ('PRIM2', {})
# ('PRIM1', {})
# ('POLA1', {})
# ('Nsp10', {})
# ('GRPEL1', {})
# ('AP2M1', {})
# ('ERGIC1', {})
# ('GFER', {})
# ('AP2A2', {})
# ('Nsp11', {})
# ('TBCA', {})
# ('Nsp12', {})
# ('PLEKHA5', {})
# ('PPIL3', {})
# ('TCF12', {})
# ('RBM41', {})
# ('LARP4B', {})
# ('ZC3H7A', {})
# ('USP54', {})
# ('CRTC3', {})
# ('ZNF318', {})
# ('UBAP2', {})
# ('PRRC2B', {})
# ('PDZD11', {})
# ('TYSND1', {})
# ('UBAP2L', {})
# ('RIPK1', {})
# ('SLU7', {})
# ('MYCBP2', {})
# ('AKAP8', {})
# ('BCKDK', {})
# Graph named 'SARS Cov2 VirHostPPIData' with 358 nodes and 479 edges

# %%
nodes_I=I.nodes()
print(nodes_I)
print(type(nodes_I))
# Out:
# ['Nsp13', 'NINL', 'HOOK1', 'TBK1', 'CEP250', 'C1orf50', 'FYCO1', 'GORASP1', 'AKAP9', 'CDK5RAP2', 'JAKMIP1', 'GCC1', 'USP13', 'MIPOL1', 'CEP112', 'NIN', 'CLIP4', 'GCC2', 'ERC1', 'CNTRL', 'CEP68', 'CEP135', 'PDE4DIP', 'CEP350', 'GRIPAP1', 'GOLGB1', 'GOLGA2', 'GOLGA3', 'TLE5', 'TLE3', 'TLE1', 'CENPF', 'RDX', 'PRKAR2B', 'PRKACA', 'PRKAR2A', 'CEP43', 'PCNT', 'HSBP1', 'CIT', 'TBKBP1', 'Nsp14', 'SIRT5', 'IMPDH2', 'GLA', 'Nsp15', 'RNF41', 'ARF6', 'NUTF2', 'Nsp2', 'GIGYF2', 'FKBP15', 'WASHC4', 'RAP1GDS1', 'POR', 'EIF4E2', 'SLC27A2', 'Nsp4', 'TIMM9', 'TIMM10B', 'DNAJC11', 'TIMM29', 'NUP210', 'ALG11', 'TIMM10', 'IDE', 'Nsp5', 'HDAC2', 'Nsp5 C145A', 'TRMT1', 'GPX1', 'Nsp6', 'ATP13A3', 'SIGMAR1', 'ATP6AP1', 'ATP5MG', 'Nsp7', 'CYB5R3', 'RAB18', 'PTGES2', 'SELENOS', 'DNAJC19', 'FAM162A', 'DCAKD', 'NAT14', 'SCARB1', 'SCCPDH', 'NDUFAF2', 'HS2ST1', 'QSOX2', 'MTARC1', 'TOR1AIP1', 'MOGS', 'LMAN2', 'GNG5', 'GNB1', 'RAB1A', 'RHOA', 'RAB14', 'RAB10', 'RAB2A', 'RAB8A', 'RAB7A', 'RAB5C', 'COMT', 'RALA', 'ACSL3', 'CYB5B', 'AGPS', 'Nsp8', 'MRPS27', 'EXOSC2', 'MRPS5', 'MRPS2', 'HECTD1', 'AATF', 'EXOSC3', 'EXOSC5', 'SEPSECS', 'CCDC86', 'NOL10', 'NARS2', 'EXOSC8', 'NGDN', 'MEPCE', 'LARP7', 'DDX10', 'MRPS25', 'SRP54', 'SRP19', 'NSD2', 'ATE1', 'SRP72', 'MPHOSPH10', 'Nsp9', 'FBLN5', 'MAT2B', 'NUP58', 'NUP88', 'ZNF503', 'NEK9', 'SPART', 'MIB1', 'NUP54', 'EIF4H', 'DCAF7', 'NUP62', 'NUP214', 'FBN2', 'FBN1', 'GTF2F2', 'Orf10', 'ELOB', 'ELOC', 'RBX1', 'TIMM8B', 'ZYG11B', 'THTPA', 'MAP7D1', 'CUL2', 'PPT1', 'Orf3a', 'ALG5', 'SUN2', 'VPS11', 'CLCC1', 'VPS39', 'ARL6IP6', 'TRIM59', 'HMOX1', 'Orf3b', 'STOML2', 'Orf6', 'MTCH1', 'RAE1', 'NUP98', 'Orf7a', 'MDN1', 'HEATR3', 'Orf8', 'FKBP10', 'ADAM9', 'FKBP7', 'HYOU1', 'ADAMTS1', 'CHPF2', 'UGGT2', 'FBXL12', 'PLEKHF2', 'SMOC1', 'POFUT1', 'SIL1', 'EDEM3', 'ERP44', 'TM2D3', 'GDF15', 'NEU1', 'SDF2', 'HS6ST2', 'NGLY1', 'IL17RA', 'ERLEC1', 'GGH', 'EMC1', 'PUSL1', 'CHPF', 'FOXRED2', 'PLD3', 'ERO1B', 'POGLUT3', 'POGLUT2', 'NPTX1', 'OS9', 'MFGE8', 'NPC2', 'INHBE', 'PCSK6', 'LOX', 'DNMT1', 'PVR', 'COL6A1', 'CISD3', 'ITGB1', 'PLAT', 'STC2', 'TOR1A', 'PLOD2', 'Orf9b', 'BAG5', 'PTBP2', 'MARK1', 'DCTPP1', 'DPH5', 'MARK2', 'MARK3', 'TOMM70', 'CSDE1', 'CHMP2A', 'SLC9A3R1', 'Orf9c', 'PIGS', 'NDUFB9', 'TMED5', 'NDUFAF1', 'BCS1L', 'NDFIP2', 'ACAD9', 'GHITM', 'TMEM39B', 'ALG8', 'ECSIT', 'FAR2', 'PIGO', 'RETREG3', 'NLRX1', 'ERMP1', 'TAPT1', 'SLC30A6', 'TMEM97', 'DPY19L1', 'SCAP', 'F2RL1', 'ABCC1', 'WFS1', 'GPAA1', 'UBXN8', 'E', 'SLC44A2', 'ZC3H18', 'CWC27', 'BRD2', 'BRD4', 'AP3B1', 'M', 'BZW2', 'AAR2', 'AKAP8L', 'AASS', 'FAM8A1', 'RTN4', 'TARS2', 'TUBGCP2', 'SLC25A21', 'INTS4', 'REEP6', 'SAAL1', 'COQ8B', 'TUBGCP3', 'SLC30A7', 'FASTKD5', 'SLC30A9', 'PITRM1', 'ANO6', 'PMPCA', 'REEP5', 'PSMD8', 'ATP6V1A', 'GGCX', 'STOM', 'ETFA', 'ACADM', 'ATP1B1', 'YIF1A', 'PMPCB', 'N', 'FAM98A', 'LARP1', 'PABPC4', 'G3BP1', 'CSNK2B', 'CSNK2A2', 'PABPC1', 'RRP9', 'RPL36', 'RBM28', 'DDX21', 'G3BP2', 'MOV10', 'UPF1', 'SNIP1', 'Spike', 'ZDHHC5', 'GOLGA7', 'Nsp1', 'PKP2', 'COLGALT1', 'POLA2', 'PRIM2', 'PRIM1', 'POLA1', 'Nsp10', 'GRPEL1', 'AP2M1', 'ERGIC1', 'GFER', 'AP2A2', 'Nsp11', 'TBCA', 'Nsp12', 'PLEKHA5', 'PPIL3', 'TCF12', 'RBM41', 'LARP4B', 'ZC3H7A', 'USP54', 'CRTC3', 'ZNF318', 'UBAP2', 'PRRC2B', 'PDZD11', 'TYSND1', 'UBAP2L', 'RIPK1', 'SLU7', 'MYCBP2', 'AKAP8', 'BCKDK']
# <class 'networkx.classes.reportviews.NodeView'>

# %%
edges_I=I.edges()
print(edges_I)
print(type(edges_I))
# Out:
# [('Nsp13', 'NINL'), ('Nsp13', 'HOOK1'), ('Nsp13', 'TBK1'), ('Nsp13', 'CEP250'), ('Nsp13', 'C1orf50'), ('Nsp13', 'FYCO1'), ('Nsp13', 'GORASP1'), ('Nsp13', 'AKAP9'), ('Nsp13', 'CDK5RAP2'), ('Nsp13', 'JAKMIP1'), ('Nsp13', 'GCC1'), ('Nsp13', 'USP13'), ('Nsp13', 'MIPOL1'), ('Nsp13', 'CEP112'), ('Nsp13', 'NIN'), ('Nsp13', 'CLIP4'), ('Nsp13', 'GCC2'), ('Nsp13', 'ERC1'), ('Nsp13', 'CNTRL'), ('Nsp13', 'CEP68'), ('Nsp13', 'CEP135'), ('Nsp13', 'PDE4DIP'), ('Nsp13', 'CEP350'), ('Nsp13', 'GRIPAP1'), ('Nsp13', 'GOLGB1'), ('Nsp13', 'GOLGA2'), ('Nsp13', 'GOLGA3'), ('Nsp13', 'TLE5'), ('Nsp13', 'TLE3'), ('Nsp13', 'TLE1'), ('Nsp13', 'CENPF'), ('Nsp13', 'RDX'), ('Nsp13', 'PRKAR2B'), ('Nsp13', 'PRKACA'), ('Nsp13', 'PRKAR2A'), ('Nsp13', 'CEP43'), ('Nsp13', 'PCNT'), ('Nsp13', 'HSBP1'), ('Nsp13', 'CIT'), ('Nsp13', 'TBKBP1'), ('NINL', 'CEP43'), ('NINL', 'CENPF'), ('NINL', 'CDK5RAP2'), ('NINL', 'PCNT'), ('NINL', 'NIN'), ('NINL', 'CEP350'), ('NINL', 'CEP135'), ('NINL', 'CNTRL'), ('NINL', 'CEP250'), ('NINL', 'CEP68'), ('NINL', 'CEP112'), ('TBK1', 'TBKBP1'), ('CEP250', 'PCNT'), ('CEP250', 'CEP43'), ('CEP250', 'CENPF'), ('CEP250', 'CEP135'), ('CEP250', 'CEP68'), ('CEP250', 'CNTRL'), ('CEP250', 'NIN'), ('CEP250', 'CDK5RAP2'), ('CEP250', 'CEP350'), ('CEP250', 'CEP112'), ('AKAP9', 'PRKAR2B'), ('AKAP9', 'PRKAR2A'), ('AKAP9', 'PRKACA'), ('CDK5RAP2', 'CEP43'), ('CDK5RAP2', 'CENPF'), ('CDK5RAP2', 'PCNT'), ('CDK5RAP2', 'NIN'), ('CDK5RAP2', 'CEP350'), ('CDK5RAP2', 'CEP135'), ('CDK5RAP2', 'CNTRL'), ('CDK5RAP2', 'CEP68'), ('CDK5RAP2', 'CEP112'), ('CEP112', 'PCNT'), ('CEP112', 'CEP43'), ('CEP112', 'CENPF'), ('CEP112', 'CEP350'), ('CEP112', 'CEP135'), ('CEP112', 'CEP68'), ('CEP112', 'CNTRL'), ('CEP112', 'NIN'), ('NIN', 'PCNT'), ('NIN', 'CEP43'), ('NIN', 'CENPF'), ('NIN', 'CEP350'), ('NIN', 'CEP135'), ('NIN', 'CNTRL'), ('NIN', 'CEP68'), ('CNTRL', 'PCNT'), ('CNTRL', 'CEP43'), ('CNTRL', 'CENPF'), ('CNTRL', 'CEP350'), ('CNTRL', 'CEP135'), ('CNTRL', 'CEP68'), ('CEP68', 'PCNT'), ('CEP68', 'CEP43'), ('CEP68', 'CENPF'), ('CEP68', 'CEP135'), ('CEP68', 'CEP350'), ('CEP135', 'PCNT'), ('CEP135', 'CEP43'), ('CEP135', 'CENPF'), ('CEP135', 'CEP350'), ('CEP350', 'PCNT'), ('CEP350', 'CEP43'), ('CEP350', 'CENPF'), ('TLE5', 'TLE1'), ('TLE5', 'TLE3'), ('TLE3', 'TLE1'), ('CENPF', 'CEP43'), ('CENPF', 'PCNT'), ('PRKAR2B', 'PRKAR2A'), ('PRKACA', 'PRKAR2A'), ('CEP43', 'PCNT'), ('Nsp14', 'SIRT5'), ('Nsp14', 'IMPDH2'), ('Nsp14', 'GLA'), ('Nsp15', 'RNF41'), ('Nsp15', 'ARF6'), ('Nsp15', 'NUTF2'), ('Nsp2', 'GIGYF2'), ('Nsp2', 'FKBP15'), ('Nsp2', 'WASHC4'), ('Nsp2', 'RAP1GDS1'), ('Nsp2', 'POR'), ('Nsp2', 'EIF4E2'), ('Nsp2', 'SLC27A2'), ('Nsp4', 'TIMM9'), ('Nsp4', 'TIMM10B'), ('Nsp4', 'DNAJC11'), ('Nsp4', 'TIMM29'), ('Nsp4', 'NUP210'), ('Nsp4', 'ALG11'), ('Nsp4', 'TIMM10'), ('Nsp4', 'IDE'), ('TIMM9', 'TIMM10'), ('TIMM9', 'TIMM29'), ('TIMM9', 'TIMM10B'), ('TIMM10B', 'TIMM10'), ('TIMM10B', 'TIMM29'), ('TIMM29', 'TIMM10'), ('Nsp5', 'HDAC2'), ('Nsp5 C145A', 'TRMT1'), ('Nsp5 C145A', 'GPX1'), ('Nsp6', 'ATP13A3'), ('Nsp6', 'SIGMAR1'), ('Nsp6', 'ATP6AP1'), ('Nsp6', 'ATP5MG'), ('ATP13A3', 'ATP6AP1'), ('ATP13A3', 'ATP5MG'), ('ATP6AP1', 'ATP5MG'), ('Nsp7', 'CYB5R3'), ('Nsp7', 'RAB18'), ('Nsp7', 'PTGES2'), ('Nsp7', 'SELENOS'), ('Nsp7', 'DNAJC19'), ('Nsp7', 'FAM162A'), ('Nsp7', 'DCAKD'), ('Nsp7', 'NAT14'), ('Nsp7', 'SCARB1'), ('Nsp7', 'SCCPDH'), ('Nsp7', 'NDUFAF2'), ('Nsp7', 'HS2ST1'), ('Nsp7', 'QSOX2'), ('Nsp7', 'MTARC1'), ('Nsp7', 'TOR1AIP1'), ('Nsp7', 'MOGS'), ('Nsp7', 'LMAN2'), ('Nsp7', 'GNG5'), ('Nsp7', 'GNB1'), ('Nsp7', 'RAB1A'), ('Nsp7', 'RHOA'), ('Nsp7', 'RAB14'), ('Nsp7', 'RAB10'), ('Nsp7', 'RAB2A'), ('Nsp7', 'RAB8A'), ('Nsp7', 'RAB7A'), ('Nsp7', 'RAB5C'), ('Nsp7', 'COMT'), ('Nsp7', 'RALA'), ('Nsp7', 'ACSL3'), ('Nsp7', 'CYB5B'), ('Nsp7', 'AGPS'), ('GNG5', 'GNB1'), ('Nsp8', 'MRPS27'), ('Nsp8', 'EXOSC2'), ('Nsp8', 'MRPS5'), ('Nsp8', 'MRPS2'), ('Nsp8', 'HECTD1'), ('Nsp8', 'AATF'), ('Nsp8', 'EXOSC3'), ('Nsp8', 'EXOSC5'), ('Nsp8', 'SEPSECS'), ('Nsp8', 'CCDC86'), ('Nsp8', 'NOL10'), ('Nsp8', 'NARS2'), ('Nsp8',  ...
# <class 'networkx.classes.reportviews.EdgeView'>

# %%
edges_I_List=list(edges_I)
print(edges_I_List)
print(type(edges_I_List))
# Out:
# [('Nsp13', 'NINL'), ('Nsp13', 'HOOK1'), ('Nsp13', 'TBK1'), ('Nsp13', 'CEP250'), ('Nsp13', 'C1orf50'), ('Nsp13', 'FYCO1'), ('Nsp13', 'GORASP1'), ('Nsp13', 'AKAP9'), ('Nsp13', 'CDK5RAP2'), ('Nsp13', 'JAKMIP1'), ('Nsp13', 'GCC1'), ('Nsp13', 'USP13'), ('Nsp13', 'MIPOL1'), ('Nsp13', 'CEP112'), ('Nsp13', 'NIN'), ('Nsp13', 'CLIP4'), ('Nsp13', 'GCC2'), ('Nsp13', 'ERC1'), ('Nsp13', 'CNTRL'), ('Nsp13', 'CEP68'), ('Nsp13', 'CEP135'), ('Nsp13', 'PDE4DIP'), ('Nsp13', 'CEP350'), ('Nsp13', 'GRIPAP1'), ('Nsp13', 'GOLGB1'), ('Nsp13', 'GOLGA2'), ('Nsp13', 'GOLGA3'), ('Nsp13', 'TLE5'), ('Nsp13', 'TLE3'), ('Nsp13', 'TLE1'), ('Nsp13', 'CENPF'), ('Nsp13', 'RDX'), ('Nsp13', 'PRKAR2B'), ('Nsp13', 'PRKACA'), ('Nsp13', 'PRKAR2A'), ('Nsp13', 'CEP43'), ('Nsp13', 'PCNT'), ('Nsp13', 'HSBP1'), ('Nsp13', 'CIT'), ('Nsp13', 'TBKBP1'), ('NINL', 'CEP43'), ('NINL', 'CENPF'), ('NINL', 'CDK5RAP2'), ('NINL', 'PCNT'), ('NINL', 'NIN'), ('NINL', 'CEP350'), ('NINL', 'CEP135'), ('NINL', 'CNTRL'), ('NINL', 'CEP250'), ('NINL', 'CEP68'), ('NINL', 'CEP112'), ('TBK1', 'TBKBP1'), ('CEP250', 'PCNT'), ('CEP250', 'CEP43'), ('CEP250', 'CENPF'), ('CEP250', 'CEP135'), ('CEP250', 'CEP68'), ('CEP250', 'CNTRL'), ('CEP250', 'NIN'), ('CEP250', 'CDK5RAP2'), ('CEP250', 'CEP350'), ('CEP250', 'CEP112'), ('AKAP9', 'PRKAR2B'), ('AKAP9', 'PRKAR2A'), ('AKAP9', 'PRKACA'), ('CDK5RAP2', 'CEP43'), ('CDK5RAP2', 'CENPF'), ('CDK5RAP2', 'PCNT'), ('CDK5RAP2', 'NIN'), ('CDK5RAP2', 'CEP350'), ('CDK5RAP2', 'CEP135'), ('CDK5RAP2', 'CNTRL'), ('CDK5RAP2', 'CEP68'), ('CDK5RAP2', 'CEP112'), ('CEP112', 'PCNT'), ('CEP112', 'CEP43'), ('CEP112', 'CENPF'), ('CEP112', 'CEP350'), ('CEP112', 'CEP135'), ('CEP112', 'CEP68'), ('CEP112', 'CNTRL'), ('CEP112', 'NIN'), ('NIN', 'PCNT'), ('NIN', 'CEP43'), ('NIN', 'CENPF'), ('NIN', 'CEP350'), ('NIN', 'CEP135'), ('NIN', 'CNTRL'), ('NIN', 'CEP68'), ('CNTRL', 'PCNT'), ('CNTRL', 'CEP43'), ('CNTRL', 'CENPF'), ('CNTRL', 'CEP350'), ('CNTRL', 'CEP135'), ('CNTRL', 'CEP68'), ('CEP68', 'PCNT'), ('CEP68', 'CEP43'), ('CEP68', 'CENPF'), ('CEP68', 'CEP135'), ('CEP68', 'CEP350'), ('CEP135', 'PCNT'), ('CEP135', 'CEP43'), ('CEP135', 'CENPF'), ('CEP135', 'CEP350'), ('CEP350', 'PCNT'), ('CEP350', 'CEP43'), ('CEP350', 'CENPF'), ('TLE5', 'TLE1'), ('TLE5', 'TLE3'), ('TLE3', 'TLE1'), ('CENPF', 'CEP43'), ('CENPF', 'PCNT'), ('PRKAR2B', 'PRKAR2A'), ('PRKACA', 'PRKAR2A'), ('CEP43', 'PCNT'), ('Nsp14', 'SIRT5'), ('Nsp14', 'IMPDH2'), ('Nsp14', 'GLA'), ('Nsp15', 'RNF41'), ('Nsp15', 'ARF6'), ('Nsp15', 'NUTF2'), ('Nsp2', 'GIGYF2'), ('Nsp2', 'FKBP15'), ('Nsp2', 'WASHC4'), ('Nsp2', 'RAP1GDS1'), ('Nsp2', 'POR'), ('Nsp2', 'EIF4E2'), ('Nsp2', 'SLC27A2'), ('Nsp4', 'TIMM9'), ('Nsp4', 'TIMM10B'), ('Nsp4', 'DNAJC11'), ('Nsp4', 'TIMM29'), ('Nsp4', 'NUP210'), ('Nsp4', 'ALG11'), ('Nsp4', 'TIMM10'), ('Nsp4', 'IDE'), ('TIMM9', 'TIMM10'), ('TIMM9', 'TIMM29'), ('TIMM9', 'TIMM10B'), ('TIMM10B', 'TIMM10'), ('TIMM10B', 'TIMM29'), ('TIMM29', 'TIMM10'), ('Nsp5', 'HDAC2'), ('Nsp5 C145A', 'TRMT1'), ('Nsp5 C145A', 'GPX1'), ('Nsp6', 'ATP13A3'), ('Nsp6', 'SIGMAR1'), ('Nsp6', 'ATP6AP1'), ('Nsp6', 'ATP5MG'), ('ATP13A3', 'ATP6AP1'), ('ATP13A3', 'ATP5MG'), ('ATP6AP1', 'ATP5MG'), ('Nsp7', 'CYB5R3'), ('Nsp7', 'RAB18'), ('Nsp7', 'PTGES2'), ('Nsp7', 'SELENOS'), ('Nsp7', 'DNAJC19'), ('Nsp7', 'FAM162A'), ('Nsp7', 'DCAKD'), ('Nsp7', 'NAT14'), ('Nsp7', 'SCARB1'), ('Nsp7', 'SCCPDH'), ('Nsp7', 'NDUFAF2'), ('Nsp7', 'HS2ST1'), ('Nsp7', 'QSOX2'), ('Nsp7', 'MTARC1'), ('Nsp7', 'TOR1AIP1'), ('Nsp7', 'MOGS'), ('Nsp7', 'LMAN2'), ('Nsp7', 'GNG5'), ('Nsp7', 'GNB1'), ('Nsp7', 'RAB1A'), ('Nsp7', 'RHOA'), ('Nsp7', 'RAB14'), ('Nsp7', 'RAB10'), ('Nsp7', 'RAB2A'), ('Nsp7', 'RAB8A'), ('Nsp7', 'RAB7A'), ('Nsp7', 'RAB5C'), ('Nsp7', 'COMT'), ('Nsp7', 'RALA'), ('Nsp7', 'ACSL3'), ('Nsp7', 'CYB5B'), ('Nsp7', 'AGPS'), ('GNG5', 'GNB1'), ('Nsp8', 'MRPS27'), ('Nsp8', 'EXOSC2'), ('Nsp8', 'MRPS5'), ('Nsp8', 'MRPS2'), ('Nsp8', 'HECTD1'), ('Nsp8', 'AATF'), ('Nsp8', 'EXOSC3'), ('Nsp8', 'EXOSC5'), ('Nsp8', 'SEPSECS'), ('Nsp8', 'CCDC86'), ('Nsp8', 'NOL10'), ('Nsp8', 'NARS2'), ('Nsp8',  ...
# <class 'list'>

# %%
print(np.shape(edges_I_List))
# Out:
# (479, 2)

# %%
nodes_I_=list(nodes_I)
print(nodes_I_)
print(type(nodes_I_))

nodes_G_=list(nodes_G)
print(nodes_G_)
print(type(nodes_G_))
# Out:
# ['Nsp13', 'NINL', 'HOOK1', 'TBK1', 'CEP250', 'C1orf50', 'FYCO1', 'GORASP1', 'AKAP9', 'CDK5RAP2', 'JAKMIP1', 'GCC1', 'USP13', 'MIPOL1', 'CEP112', 'NIN', 'CLIP4', 'GCC2', 'ERC1', 'CNTRL', 'CEP68', 'CEP135', 'PDE4DIP', 'CEP350', 'GRIPAP1', 'GOLGB1', 'GOLGA2', 'GOLGA3', 'TLE5', 'TLE3', 'TLE1', 'CENPF', 'RDX', 'PRKAR2B', 'PRKACA', 'PRKAR2A', 'CEP43', 'PCNT', 'HSBP1', 'CIT', 'TBKBP1', 'Nsp14', 'SIRT5', 'IMPDH2', 'GLA', 'Nsp15', 'RNF41', 'ARF6', 'NUTF2', 'Nsp2', 'GIGYF2', 'FKBP15', 'WASHC4', 'RAP1GDS1', 'POR', 'EIF4E2', 'SLC27A2', 'Nsp4', 'TIMM9', 'TIMM10B', 'DNAJC11', 'TIMM29', 'NUP210', 'ALG11', 'TIMM10', 'IDE', 'Nsp5', 'HDAC2', 'Nsp5 C145A', 'TRMT1', 'GPX1', 'Nsp6', 'ATP13A3', 'SIGMAR1', 'ATP6AP1', 'ATP5MG', 'Nsp7', 'CYB5R3', 'RAB18', 'PTGES2', 'SELENOS', 'DNAJC19', 'FAM162A', 'DCAKD', 'NAT14', 'SCARB1', 'SCCPDH', 'NDUFAF2', 'HS2ST1', 'QSOX2', 'MTARC1', 'TOR1AIP1', 'MOGS', 'LMAN2', 'GNG5', 'GNB1', 'RAB1A', 'RHOA', 'RAB14', 'RAB10', 'RAB2A', 'RAB8A', 'RAB7A', 'RAB5C', 'COMT', 'RALA', 'ACSL3', 'CYB5B', 'AGPS', 'Nsp8', 'MRPS27', 'EXOSC2', 'MRPS5', 'MRPS2', 'HECTD1', 'AATF', 'EXOSC3', 'EXOSC5', 'SEPSECS', 'CCDC86', 'NOL10', 'NARS2', 'EXOSC8', 'NGDN', 'MEPCE', 'LARP7', 'DDX10', 'MRPS25', 'SRP54', 'SRP19', 'NSD2', 'ATE1', 'SRP72', 'MPHOSPH10', 'Nsp9', 'FBLN5', 'MAT2B', 'NUP58', 'NUP88', 'ZNF503', 'NEK9', 'SPART', 'MIB1', 'NUP54', 'EIF4H', 'DCAF7', 'NUP62', 'NUP214', 'FBN2', 'FBN1', 'GTF2F2', 'Orf10', 'ELOB', 'ELOC', 'RBX1', 'TIMM8B', 'ZYG11B', 'THTPA', 'MAP7D1', 'CUL2', 'PPT1', 'Orf3a', 'ALG5', 'SUN2', 'VPS11', 'CLCC1', 'VPS39', 'ARL6IP6', 'TRIM59', 'HMOX1', 'Orf3b', 'STOML2', 'Orf6', 'MTCH1', 'RAE1', 'NUP98', 'Orf7a', 'MDN1', 'HEATR3', 'Orf8', 'FKBP10', 'ADAM9', 'FKBP7', 'HYOU1', 'ADAMTS1', 'CHPF2', 'UGGT2', 'FBXL12', 'PLEKHF2', 'SMOC1', 'POFUT1', 'SIL1', 'EDEM3', 'ERP44', 'TM2D3', 'GDF15', 'NEU1', 'SDF2', 'HS6ST2', 'NGLY1', 'IL17RA', 'ERLEC1', 'GGH', 'EMC1', 'PUSL1', 'CHPF', 'FOXRED2', 'PLD3', 'ERO1B', 'POGLUT3', 'POGLUT2', 'NPTX1', 'OS9', 'MFGE8', 'NPC2', 'INHBE', 'PCSK6', 'LOX', 'DNMT1', 'PVR', 'COL6A1', 'CISD3', 'ITGB1', 'PLAT', 'STC2', 'TOR1A', 'PLOD2', 'Orf9b', 'BAG5', 'PTBP2', 'MARK1', 'DCTPP1', 'DPH5', 'MARK2', 'MARK3', 'TOMM70', 'CSDE1', 'CHMP2A', 'SLC9A3R1', 'Orf9c', 'PIGS', 'NDUFB9', 'TMED5', 'NDUFAF1', 'BCS1L', 'NDFIP2', 'ACAD9', 'GHITM', 'TMEM39B', 'ALG8', 'ECSIT', 'FAR2', 'PIGO', 'RETREG3', 'NLRX1', 'ERMP1', 'TAPT1', 'SLC30A6', 'TMEM97', 'DPY19L1', 'SCAP', 'F2RL1', 'ABCC1', 'WFS1', 'GPAA1', 'UBXN8', 'E', 'SLC44A2', 'ZC3H18', 'CWC27', 'BRD2', 'BRD4', 'AP3B1', 'M', 'BZW2', 'AAR2', 'AKAP8L', 'AASS', 'FAM8A1', 'RTN4', 'TARS2', 'TUBGCP2', 'SLC25A21', 'INTS4', 'REEP6', 'SAAL1', 'COQ8B', 'TUBGCP3', 'SLC30A7', 'FASTKD5', 'SLC30A9', 'PITRM1', 'ANO6', 'PMPCA', 'REEP5', 'PSMD8', 'ATP6V1A', 'GGCX', 'STOM', 'ETFA', 'ACADM', 'ATP1B1', 'YIF1A', 'PMPCB', 'N', 'FAM98A', 'LARP1', 'PABPC4', 'G3BP1', 'CSNK2B', 'CSNK2A2', 'PABPC1', 'RRP9', 'RPL36', 'RBM28', 'DDX21', 'G3BP2', 'MOV10', 'UPF1', 'SNIP1', 'Spike', 'ZDHHC5', 'GOLGA7', 'Nsp1', 'PKP2', 'COLGALT1', 'POLA2', 'PRIM2', 'PRIM1', 'POLA1', 'Nsp10', 'GRPEL1', 'AP2M1', 'ERGIC1', 'GFER', 'AP2A2', 'Nsp11', 'TBCA', 'Nsp12', 'PLEKHA5', 'PPIL3', 'TCF12', 'RBM41', 'LARP4B', 'ZC3H7A', 'USP54', 'CRTC3', 'ZNF318', 'UBAP2', 'PRRC2B', 'PDZD11', 'TYSND1', 'UBAP2L', 'RIPK1', 'SLU7', 'MYCBP2', 'AKAP8', 'BCKDK']
# <class 'list'>
# ['MED19', 'POLR2D', 'POLR2B', 'POLR2C', 'POLR2E', 'POLR2F', 'POLR2G', 'POLR2H', 'POLR2I', 'POLR2L', 'RADIL', 'NFKBIA', 'DCK', 'ZC3H13', 'APP', 'FBXW7', 'POLR2K', 'ELL2', 'AFF4', 'MSX1', 'RPAP2', 'HECTD1', 'HERC2', 'NR2C2', 'DTX2', 'NEDD9', 'OSTF1', 'HLCS', 'GRB2', 'KANK2', 'SMAD1', 'SMAD2', 'UBR5', 'CHMP4B', 'BRD4', 'CHD9', 'SRSF3', 'CDC23', 'ZCCHC10', 'UBTF', 'ANAPC2', 'ZNF281', 'HCFC1', 'NOLC1', 'FBL', 'TCOF1', 'RUVBL1', 'RANGAP1', 'PPIG', 'NOL8', 'PNN', 'LMNA', 'AHCTF1', 'SMC4', 'ANAPC5', 'IPO4', 'RNPS1', 'PRPF4B', 'DDX21', 'DDB1', 'NUMA1', 'KPNA2', 'HSPD1', 'HSPA9', 'MYBBP1A', 'DNM2', 'DNAJA1', 'ZBTB9', 'LUC7L3', 'DDX20', 'CMSS1', 'NPM1', 'DDX50', 'HDAC6', 'TARDBP', 'PTBP1', 'DDX3X', 'NOP58', 'SNRPD1', 'BAG2', 'DDX52', 'U2SURP', 'HNRNPM', 'DNALI1', 'EEF1A1', 'NONO', 'GCN1', 'TMPO', 'RSL1D1', 'ACIN1', 'TTN', 'RBM39', 'DHRS7B', 'PRKCA', 'YWHAG', 'SETDB1', 'KAT5', 'LMO3', 'GTPBP10', 'MRPL58', 'CAND1', 'GOLGA2', 'PNMA1', 'PCBP4', 'MRPS30', 'RCC1L', 'BPNT1', 'MRPL50', 'MECP2', 'SUCLA2', 'PLEKHO1', 'PTPN2', 'EFTUD2', 'HABP4', 'SERBP1', 'MRM1', 'TRMT61B', 'IRF2', 'SNRNP70', 'H2BC21', 'ESR1', 'IMMP2L', 'GRSF1', 'ACAD9', 'AUH', 'C12orf65', 'C1QBP', 'MTRES1', 'CHCHD1', 'CS', 'GFM1', 'GFM2', 'LRPPRC', 'MDH2', 'METTL15', 'METTL17', 'MRPL11', 'MRPS12', 'MRPS26', 'MRRF', 'MTERF3', 'MTG1', 'MTIF2', 'MTIF3', 'MTRF1', 'MTRF1L', 'PMPCA', 'PMPCB', 'RPUSD4', 'SSBP1', 'TACO1', 'TRUB2', 'TSFM', 'TUFM', 'EXD2', 'CLPP', 'LGALS9', 'MGST3', 'ATAD3B', 'ATAD3A', 'VPS37C', 'UBC', 'MVB12A', 'TLE5', 'XIAP', 'DDIT3', 'PKNOX1', 'PLSCR1', 'SH3GL1', 'SORBS2', 'DAZAP2', 'SORBS3', 'STAM2', 'TFG', 'RBPMS', 'WWP2', 'HNRNPUL1', 'FAM168A', 'TFIP11', 'RINT1', 'MAPK1IP1L', 'HOXB5', 'TRIM14', 'TNIP2', 'AGO2', 'LASP1', 'POLR2J', 'ZMYND12', 'BIRC7', 'RPRD1B', 'KLF1', 'ABHD11', 'POU2AF1', 'ILF3', 'CBFA2T3', 'GPS2', 'UBAP2', 'DCTN3', 'FCHSD2', 'NUP54', 'YTHDF1', 'TIAL1', 'HAUS1', 'SH3RF1', 'BAG4', 'NTAQ1', 'PEF1', 'FUBP1', 'PKNOX2', 'TSC1', 'RAMAC', 'HNRNPF', 'HYI', 'WWOX', 'PLEKHG4', 'ZNF34', 'LAGE3', 'STH', 'ARHGEF6', 'PARP2', 'PDLIM7', 'CNOT1', 'USP22', 'GTF2A1', 'SIRT7', 'NOTCH1', 'EPAS1', 'FN1', 'PEX14', 'PPP6R1', 'KRT18', 'POLR1C', 'OBI1', 'FBXW11', 'TNRC6A', 'RXRA', 'CCDC8', 'MMP7', 'CAPZA2', 'TNRC6B', 'IFI16', 'BTRC', 'MED4', 'SSX2IP', 'CNTROB', 'NINL', 'CENPJ', 'XPO1', 'ABCF1', 'ATRX', 'CAPZA1', 'CAPZB', 'FHL2', 'RPS27', 'SDCBP', 'TOB2', 'BTG3', 'NUP42', 'REEP5', 'BAG6', 'IBTK', 'SND1', 'AURKAIP1', 'PI4K2A', 'GPBP1L1', 'INTS5', 'TNKS1BP1', 'RAVER1', 'DDX6', 'SNW1', 'CDC5L', 'RC3H1', 'GADD45B', 'TRIM25', 'G3BP1', 'HNRNPL', 'STK40', 'FBXO7', 'HIF1AN', 'EGLN3', 'RMND5A', 'RNF4', 'POLR2A', 'ESR2', 'RNF123', 'AGR2', 'SUZ12', 'MED14', 'WDR76', 'GRWD1', 'VIRMA', 'RC3H2', 'ZC3H7A', 'TANK', 'USP14', 'DYRK1A', 'ANXA2R', 'LGALS3BP', 'BIRC3', 'STAU1', 'TRIM28', 'MIB1', 'ANKRD55', 'ANKRD17', 'CAPRIN1', 'CEP85', 'FAM193A', 'GPBP1', 'CPEB4', 'CSDE1', 'CTIF', 'EIF4ENIF1', 'FAM120C', 'FUBP3', 'FXR2', 'GARRE1', 'LSM14A', 'LZTS2', 'MKRN2', 'MOV10', 'NUFIP2', 'PABPC1', 'PAIP1', 'PAIP2', 'PATL1', 'PRRC2A', 'PUM1', 'R3HDM2', 'RBMS1', 'SAMD4B', 'ENTR1', 'SMAP2', 'SMG7', 'TDRD3', 'UBAP2L', 'UNK', 'YTHDF2', 'YTHDF3', 'ZC3HAV1', 'ZFP36', 'TUBB3', 'TXNL1', 'PRRC2B', 'SMG6', 'LRRC59', 'CDC42', 'THRB', 'VCAM1', 'JUN', 'KSR1', 'LRRK2', 'ZDHHC5', 'RARA', 'PPARG', 'FAM83G', 'YWHAQ', 'SH3KBP1', 'SMAD3', 'CSNK1A1', 'NXF1', 'VAPB', 'YWHAH', 'VAPA', 'CRBN', 'NIN', 'YWHAB', 'CSNK1D', 'CSNK1E', 'WIPF3', 'DNMBP', 'NCK2', 'ACTC1', 'ITSN1', 'ITSN2', 'VSTM2L', 'ARHGAP32', 'SFN', 'GAB2', 'GAB1', 'ARRB1', 'FZR1', 'SMURF1', 'DZIP3', 'ABI2', 'ZWINT', 'HNRNPD', 'SORT1', 'SYNCRIP', 'SGTB', 'PTPRK', 'ASB3', 'BICD1', 'OBSL1', 'CUL7', 'GPHN', 'SEC61B', 'CBS', 'PRDX4', 'SEC16A', 'ADAM10', 'GRAP', 'SFI1', 'KRT19', 'CETN2', 'LPXN', 'MAD2L2', 'SERTAD1', 'CCDC57', 'CETN1', 'USP9X', 'LMNB2', 'PPP1CA', 'MIF4GD', 'HGS', 'DDX19A', 'SVIL', 'UBQLN4', 'HINFP', 'DHX16', 'ILF2', 'PDXDC1', 'LSM5', 'HDAC4', 'EXOSC6', 'PDE4DIP', 'PSMC1', 'SLBP', 'BMT2', 'SMARCB1', 'APEX1', 'CHCHD2', 'ENKD1', 'FAM110A', 'EIF3G', 'ATPAF2', 'AQP1' ...
# <class 'list'>

# %%
def intersection(lst1, lst2):
    lst3 = [value for value in lst1 if value in lst2]
    return lst3

print(intersection(nodes_I_, nodes_G_))
print(len(intersection(nodes_I_, nodes_G_)))
# Out:
# ['NINL', 'TBK1', 'CEP250', 'C1orf50', 'FYCO1', 'GORASP1', 'AKAP9', 'CDK5RAP2', 'GCC1', 'USP13', 'CEP112', 'NIN', 'CLIP4', 'GCC2', 'ERC1', 'CNTRL', 'CEP68', 'CEP135', 'PDE4DIP', 'CEP350', 'GRIPAP1', 'GOLGB1', 'GOLGA2', 'GOLGA3', 'TLE5', 'TLE3', 'TLE1', 'RDX', 'PRKAR2B', 'PRKACA', 'PRKAR2A', 'CEP43', 'PCNT', 'HSBP1', 'SIRT5', 'IMPDH2', 'GLA', 'ARF6', 'GIGYF2', 'FKBP15', 'WASHC4', 'RAP1GDS1', 'POR', 'EIF4E2', 'TIMM9', 'TIMM10B', 'DNAJC11', 'NUP210', 'TIMM10', 'IDE', 'HDAC2', 'TRMT1', 'GPX1', 'ATP13A3', 'SIGMAR1', 'ATP6AP1', 'ATP5MG', 'CYB5R3', 'RAB18', 'PTGES2', 'SELENOS', 'DNAJC19', 'FAM162A', 'NAT14', 'SCARB1', 'SCCPDH', 'NDUFAF2', 'HS2ST1', 'QSOX2', 'TOR1AIP1', 'MOGS', 'LMAN2', 'GNG5', 'GNB1', 'RAB1A', 'RHOA', 'RAB14', 'RAB10', 'RAB2A', 'RAB8A', 'RAB7A', 'RAB5C', 'COMT', 'RALA', 'ACSL3', 'CYB5B', 'AGPS', 'MRPS27', 'EXOSC2', 'MRPS5', 'MRPS2', 'HECTD1', 'AATF', 'EXOSC3', 'EXOSC5', 'SEPSECS', 'CCDC86', 'NOL10', 'NARS2', 'EXOSC8', 'NGDN', 'MEPCE', 'LARP7', 'DDX10', 'MRPS25', 'SRP54', 'SRP19', 'NSD2', 'ATE1', 'SRP72', 'MPHOSPH10', 'FBLN5', 'MAT2B', 'NUP58', 'NUP88', 'ZNF503', 'NEK9', 'SPART', 'MIB1', 'NUP54', 'EIF4H', 'DCAF7', 'NUP62', 'NUP214', 'FBN1', 'ELOB', 'ELOC', 'RBX1', 'TIMM8B', 'ZYG11B', 'THTPA', 'MAP7D1', 'CUL2', 'PPT1', 'ALG5', 'SUN2', 'VPS11', 'CLCC1', 'VPS39', 'ARL6IP6', 'TRIM59', 'HMOX1', 'STOML2', 'MTCH1', 'RAE1', 'NUP98', 'MDN1', 'HEATR3', 'ADAM9', 'FKBP7', 'HYOU1', 'ADAMTS1', 'CHPF2', 'FBXL12', 'PLEKHF2', 'SMOC1', 'SIL1', 'EDEM3', 'ERP44', 'TM2D3', 'GDF15', 'NEU1', 'SDF2', 'NGLY1', 'IL17RA', 'ERLEC1', 'GGH', 'EMC1', 'CHPF', 'PLD3', 'ERO1B', 'POGLUT3', 'NPTX1', 'OS9', 'MFGE8', 'NPC2', 'LOX', 'DNMT1', 'PVR', 'COL6A1', 'CISD3', 'ITGB1', 'PLAT', 'STC2', 'TOR1A', 'PLOD2', 'BAG5', 'PTBP2', 'MARK1', 'DCTPP1', 'DPH5', 'MARK3', 'TOMM70', 'CSDE1', 'CHMP2A', 'SLC9A3R1', 'PIGS', 'NDUFB9', 'TMED5', 'NDUFAF1', 'BCS1L', 'NDFIP2', 'ACAD9', 'GHITM', 'TMEM39B', 'ALG8', 'ECSIT', 'FAR2', 'PIGO', 'RETREG3', 'NLRX1', 'ERMP1', 'TAPT1', 'SLC30A6', 'TMEM97', 'DPY19L1', 'SCAP', 'F2RL1', 'ABCC1', 'WFS1', 'GPAA1', 'UBXN8', 'SLC44A2', 'ZC3H18', 'CWC27', 'BRD2', 'BRD4', 'AP3B1', 'BZW2', 'AAR2', 'AKAP8L', 'AASS', 'FAM8A1', 'RTN4', 'TARS2', 'TUBGCP2', 'INTS4', 'SAAL1', 'COQ8B', 'TUBGCP3', 'SLC30A7', 'FASTKD5', 'SLC30A9', 'PITRM1', 'ANO6', 'PMPCA', 'REEP5', 'PSMD8', 'ATP6V1A', 'GGCX', 'STOM', 'ETFA', 'ACADM', 'ATP1B1', 'YIF1A', 'PMPCB', 'FAM98A', 'LARP1', 'PABPC4', 'G3BP1', 'CSNK2B', 'CSNK2A2', 'PABPC1', 'RPL36', 'RBM28', 'DDX21', 'G3BP2', 'MOV10', 'UPF1', 'SNIP1', 'ZDHHC5', 'GOLGA7', 'COLGALT1', 'PRIM1', 'POLA1', 'GRPEL1', 'AP2M1', 'ERGIC1', 'GFER', 'AP2A2', 'TBCA', 'PLEKHA5', 'PPIL3', 'TCF12', 'LARP4B', 'ZC3H7A', 'USP54', 'CRTC3', 'ZNF318', 'UBAP2', 'PRRC2B', 'PDZD11', 'UBAP2L', 'RIPK1', 'SLU7', 'MYCBP2', 'AKAP8', 'BCKDK']
# 298

# %%
J=nx.compose(G,I)

# %%
nx.draw(J)
plt.show()

# %%
nodes_J=J.nodes()
print(nodes_J)
print(type(nodes_J))
print('##################')
nodes_J_=list(nodes_J)
print(nodes_J_)
print(type(nodes_J_))
print('##################')
print(np.shape(nodes_J_))
# Out:
# ['MED19', 'POLR2D', 'POLR2B', 'POLR2C', 'POLR2E', 'POLR2F', 'POLR2G', 'POLR2H', 'POLR2I', 'POLR2L', 'RADIL', 'NFKBIA', 'DCK', 'ZC3H13', 'APP', 'FBXW7', 'POLR2K', 'ELL2', 'AFF4', 'MSX1', 'RPAP2', 'HECTD1', 'HERC2', 'NR2C2', 'DTX2', 'NEDD9', 'OSTF1', 'HLCS', 'GRB2', 'KANK2', 'SMAD1', 'SMAD2', 'UBR5', 'CHMP4B', 'BRD4', 'CHD9', 'SRSF3', 'CDC23', 'ZCCHC10', 'UBTF', 'ANAPC2', 'ZNF281', 'HCFC1', 'NOLC1', 'FBL', 'TCOF1', 'RUVBL1', 'RANGAP1', 'PPIG', 'NOL8', 'PNN', 'LMNA', 'AHCTF1', 'SMC4', 'ANAPC5', 'IPO4', 'RNPS1', 'PRPF4B', 'DDX21', 'DDB1', 'NUMA1', 'KPNA2', 'HSPD1', 'HSPA9', 'MYBBP1A', 'DNM2', 'DNAJA1', 'ZBTB9', 'LUC7L3', 'DDX20', 'CMSS1', 'NPM1', 'DDX50', 'HDAC6', 'TARDBP', 'PTBP1', 'DDX3X', 'NOP58', 'SNRPD1', 'BAG2', 'DDX52', 'U2SURP', 'HNRNPM', 'DNALI1', 'EEF1A1', 'NONO', 'GCN1', 'TMPO', 'RSL1D1', 'ACIN1', 'TTN', 'RBM39', 'DHRS7B', 'PRKCA', 'YWHAG', 'SETDB1', 'KAT5', 'LMO3', 'GTPBP10', 'MRPL58', 'CAND1', 'GOLGA2', 'PNMA1', 'PCBP4', 'MRPS30', 'RCC1L', 'BPNT1', 'MRPL50', 'MECP2', 'SUCLA2', 'PLEKHO1', 'PTPN2', 'EFTUD2', 'HABP4', 'SERBP1', 'MRM1', 'TRMT61B', 'IRF2', 'SNRNP70', 'H2BC21', 'ESR1', 'IMMP2L', 'GRSF1', 'ACAD9', 'AUH', 'C12orf65', 'C1QBP', 'MTRES1', 'CHCHD1', 'CS', 'GFM1', 'GFM2', 'LRPPRC', 'MDH2', 'METTL15', 'METTL17', 'MRPL11', 'MRPS12', 'MRPS26', 'MRRF', 'MTERF3', 'MTG1', 'MTIF2', 'MTIF3', 'MTRF1', 'MTRF1L', 'PMPCA', 'PMPCB', 'RPUSD4', 'SSBP1', 'TACO1', 'TRUB2', 'TSFM', 'TUFM', 'EXD2', 'CLPP', 'LGALS9', 'MGST3', 'ATAD3B', 'ATAD3A', 'VPS37C', 'UBC', 'MVB12A', 'TLE5', 'XIAP', 'DDIT3', 'PKNOX1', 'PLSCR1', 'SH3GL1', 'SORBS2', 'DAZAP2', 'SORBS3', 'STAM2', 'TFG', 'RBPMS', 'WWP2', 'HNRNPUL1', 'FAM168A', 'TFIP11', 'RINT1', 'MAPK1IP1L', 'HOXB5', 'TRIM14', 'TNIP2', 'AGO2', 'LASP1', 'POLR2J', 'ZMYND12', 'BIRC7', 'RPRD1B', 'KLF1', 'ABHD11', 'POU2AF1', 'ILF3', 'CBFA2T3', 'GPS2', 'UBAP2', 'DCTN3', 'FCHSD2', 'NUP54', 'YTHDF1', 'TIAL1', 'HAUS1', 'SH3RF1', 'BAG4', 'NTAQ1', 'PEF1', 'FUBP1', 'PKNOX2', 'TSC1', 'RAMAC', 'HNRNPF', 'HYI', 'WWOX', 'PLEKHG4', 'ZNF34', 'LAGE3', 'STH', 'ARHGEF6', 'PARP2', 'PDLIM7', 'CNOT1', 'USP22', 'GTF2A1', 'SIRT7', 'NOTCH1', 'EPAS1', 'FN1', 'PEX14', 'PPP6R1', 'KRT18', 'POLR1C', 'OBI1', 'FBXW11', 'TNRC6A', 'RXRA', 'CCDC8', 'MMP7', 'CAPZA2', 'TNRC6B', 'IFI16', 'BTRC', 'MED4', 'SSX2IP', 'CNTROB', 'NINL', 'CENPJ', 'XPO1', 'ABCF1', 'ATRX', 'CAPZA1', 'CAPZB', 'FHL2', 'RPS27', 'SDCBP', 'TOB2', 'BTG3', 'NUP42', 'REEP5', 'BAG6', 'IBTK', 'SND1', 'AURKAIP1', 'PI4K2A', 'GPBP1L1', 'INTS5', 'TNKS1BP1', 'RAVER1', 'DDX6', 'SNW1', 'CDC5L', 'RC3H1', 'GADD45B', 'TRIM25', 'G3BP1', 'HNRNPL', 'STK40', 'FBXO7', 'HIF1AN', 'EGLN3', 'RMND5A', 'RNF4', 'POLR2A', 'ESR2', 'RNF123', 'AGR2', 'SUZ12', 'MED14', 'WDR76', 'GRWD1', 'VIRMA', 'RC3H2', 'ZC3H7A', 'TANK', 'USP14', 'DYRK1A', 'ANXA2R', 'LGALS3BP', 'BIRC3', 'STAU1', 'TRIM28', 'MIB1', 'ANKRD55', 'ANKRD17', 'CAPRIN1', 'CEP85', 'FAM193A', 'GPBP1', 'CPEB4', 'CSDE1', 'CTIF', 'EIF4ENIF1', 'FAM120C', 'FUBP3', 'FXR2', 'GARRE1', 'LSM14A', 'LZTS2', 'MKRN2', 'MOV10', 'NUFIP2', 'PABPC1', 'PAIP1', 'PAIP2', 'PATL1', 'PRRC2A', 'PUM1', 'R3HDM2', 'RBMS1', 'SAMD4B', 'ENTR1', 'SMAP2', 'SMG7', 'TDRD3', 'UBAP2L', 'UNK', 'YTHDF2', 'YTHDF3', 'ZC3HAV1', 'ZFP36', 'TUBB3', 'TXNL1', 'PRRC2B', 'SMG6', 'LRRC59', 'CDC42', 'THRB', 'VCAM1', 'JUN', 'KSR1', 'LRRK2', 'ZDHHC5', 'RARA', 'PPARG', 'FAM83G', 'YWHAQ', 'SH3KBP1', 'SMAD3', 'CSNK1A1', 'NXF1', 'VAPB', 'YWHAH', 'VAPA', 'CRBN', 'NIN', 'YWHAB', 'CSNK1D', 'CSNK1E', 'WIPF3', 'DNMBP', 'NCK2', 'ACTC1', 'ITSN1', 'ITSN2', 'VSTM2L', 'ARHGAP32', 'SFN', 'GAB2', 'GAB1', 'ARRB1', 'FZR1', 'SMURF1', 'DZIP3', 'ABI2', 'ZWINT', 'HNRNPD', 'SORT1', 'SYNCRIP', 'SGTB', 'PTPRK', 'ASB3', 'BICD1', 'OBSL1', 'CUL7', 'GPHN', 'SEC61B', 'CBS', 'PRDX4', 'SEC16A', 'ADAM10', 'GRAP', 'SFI1', 'KRT19', 'CETN2', 'LPXN', 'MAD2L2', 'SERTAD1', 'CCDC57', 'CETN1', 'USP9X', 'LMNB2', 'PPP1CA', 'MIF4GD', 'HGS', 'DDX19A', 'SVIL', 'UBQLN4', 'HINFP', 'DHX16', 'ILF2', 'PDXDC1', 'LSM5', 'HDAC4', 'EXOSC6', 'PDE4DIP', 'PSMC1', 'SLBP', 'BMT2', 'SMARCB1', 'APEX1', 'CHCHD2', 'ENKD1', 'FAM110A', 'EIF3G', 'ATPAF2', 'AQP1' ...
# <class 'networkx.classes.reportviews.NodeView'>
# ##################
# ['MED19', 'POLR2D', 'POLR2B', 'POLR2C', 'POLR2E', 'POLR2F', 'POLR2G', 'POLR2H', 'POLR2I', 'POLR2L', 'RADIL', 'NFKBIA', 'DCK', 'ZC3H13', 'APP', 'FBXW7', 'POLR2K', 'ELL2', 'AFF4', 'MSX1', 'RPAP2', 'HECTD1', 'HERC2', 'NR2C2', 'DTX2', 'NEDD9', 'OSTF1', 'HLCS', 'GRB2', 'KANK2', 'SMAD1', 'SMAD2', 'UBR5', 'CHMP4B', 'BRD4', 'CHD9', 'SRSF3', 'CDC23', 'ZCCHC10', 'UBTF', 'ANAPC2', 'ZNF281', 'HCFC1', 'NOLC1', 'FBL', 'TCOF1', 'RUVBL1', 'RANGAP1', 'PPIG', 'NOL8', 'PNN', 'LMNA', 'AHCTF1', 'SMC4', 'ANAPC5', 'IPO4', 'RNPS1', 'PRPF4B', 'DDX21', 'DDB1', 'NUMA1', 'KPNA2', 'HSPD1', 'HSPA9', 'MYBBP1A', 'DNM2', 'DNAJA1', 'ZBTB9', 'LUC7L3', 'DDX20', 'CMSS1', 'NPM1', 'DDX50', 'HDAC6', 'TARDBP', 'PTBP1', 'DDX3X', 'NOP58', 'SNRPD1', 'BAG2', 'DDX52', 'U2SURP', 'HNRNPM', 'DNALI1', 'EEF1A1', 'NONO', 'GCN1', 'TMPO', 'RSL1D1', 'ACIN1', 'TTN', 'RBM39', 'DHRS7B', 'PRKCA', 'YWHAG', 'SETDB1', 'KAT5', 'LMO3', 'GTPBP10', 'MRPL58', 'CAND1', 'GOLGA2', 'PNMA1', 'PCBP4', 'MRPS30', 'RCC1L', 'BPNT1', 'MRPL50', 'MECP2', 'SUCLA2', 'PLEKHO1', 'PTPN2', 'EFTUD2', 'HABP4', 'SERBP1', 'MRM1', 'TRMT61B', 'IRF2', 'SNRNP70', 'H2BC21', 'ESR1', 'IMMP2L', 'GRSF1', 'ACAD9', 'AUH', 'C12orf65', 'C1QBP', 'MTRES1', 'CHCHD1', 'CS', 'GFM1', 'GFM2', 'LRPPRC', 'MDH2', 'METTL15', 'METTL17', 'MRPL11', 'MRPS12', 'MRPS26', 'MRRF', 'MTERF3', 'MTG1', 'MTIF2', 'MTIF3', 'MTRF1', 'MTRF1L', 'PMPCA', 'PMPCB', 'RPUSD4', 'SSBP1', 'TACO1', 'TRUB2', 'TSFM', 'TUFM', 'EXD2', 'CLPP', 'LGALS9', 'MGST3', 'ATAD3B', 'ATAD3A', 'VPS37C', 'UBC', 'MVB12A', 'TLE5', 'XIAP', 'DDIT3', 'PKNOX1', 'PLSCR1', 'SH3GL1', 'SORBS2', 'DAZAP2', 'SORBS3', 'STAM2', 'TFG', 'RBPMS', 'WWP2', 'HNRNPUL1', 'FAM168A', 'TFIP11', 'RINT1', 'MAPK1IP1L', 'HOXB5', 'TRIM14', 'TNIP2', 'AGO2', 'LASP1', 'POLR2J', 'ZMYND12', 'BIRC7', 'RPRD1B', 'KLF1', 'ABHD11', 'POU2AF1', 'ILF3', 'CBFA2T3', 'GPS2', 'UBAP2', 'DCTN3', 'FCHSD2', 'NUP54', 'YTHDF1', 'TIAL1', 'HAUS1', 'SH3RF1', 'BAG4', 'NTAQ1', 'PEF1', 'FUBP1', 'PKNOX2', 'TSC1', 'RAMAC', 'HNRNPF', 'HYI', 'WWOX', 'PLEKHG4', 'ZNF34', 'LAGE3', 'STH', 'ARHGEF6', 'PARP2', 'PDLIM7', 'CNOT1', 'USP22', 'GTF2A1', 'SIRT7', 'NOTCH1', 'EPAS1', 'FN1', 'PEX14', 'PPP6R1', 'KRT18', 'POLR1C', 'OBI1', 'FBXW11', 'TNRC6A', 'RXRA', 'CCDC8', 'MMP7', 'CAPZA2', 'TNRC6B', 'IFI16', 'BTRC', 'MED4', 'SSX2IP', 'CNTROB', 'NINL', 'CENPJ', 'XPO1', 'ABCF1', 'ATRX', 'CAPZA1', 'CAPZB', 'FHL2', 'RPS27', 'SDCBP', 'TOB2', 'BTG3', 'NUP42', 'REEP5', 'BAG6', 'IBTK', 'SND1', 'AURKAIP1', 'PI4K2A', 'GPBP1L1', 'INTS5', 'TNKS1BP1', 'RAVER1', 'DDX6', 'SNW1', 'CDC5L', 'RC3H1', 'GADD45B', 'TRIM25', 'G3BP1', 'HNRNPL', 'STK40', 'FBXO7', 'HIF1AN', 'EGLN3', 'RMND5A', 'RNF4', 'POLR2A', 'ESR2', 'RNF123', 'AGR2', 'SUZ12', 'MED14', 'WDR76', 'GRWD1', 'VIRMA', 'RC3H2', 'ZC3H7A', 'TANK', 'USP14', 'DYRK1A', 'ANXA2R', 'LGALS3BP', 'BIRC3', 'STAU1', 'TRIM28', 'MIB1', 'ANKRD55', 'ANKRD17', 'CAPRIN1', 'CEP85', 'FAM193A', 'GPBP1', 'CPEB4', 'CSDE1', 'CTIF', 'EIF4ENIF1', 'FAM120C', 'FUBP3', 'FXR2', 'GARRE1', 'LSM14A', 'LZTS2', 'MKRN2', 'MOV10', 'NUFIP2', 'PABPC1', 'PAIP1', 'PAIP2', 'PATL1', 'PRRC2A', 'PUM1', 'R3HDM2', 'RBMS1', 'SAMD4B', 'ENTR1', 'SMAP2', 'SMG7', 'TDRD3', 'UBAP2L', 'UNK', 'YTHDF2', 'YTHDF3', 'ZC3HAV1', 'ZFP36', 'TUBB3', 'TXNL1', 'PRRC2B', 'SMG6', 'LRRC59', 'CDC42', 'THRB', 'VCAM1', 'JUN', 'KSR1', 'LRRK2', 'ZDHHC5', 'RARA', 'PPARG', 'FAM83G', 'YWHAQ', 'SH3KBP1', 'SMAD3', 'CSNK1A1', 'NXF1', 'VAPB', 'YWHAH', 'VAPA', 'CRBN', 'NIN', 'YWHAB', 'CSNK1D', 'CSNK1E', 'WIPF3', 'DNMBP', 'NCK2', 'ACTC1', 'ITSN1', 'ITSN2', 'VSTM2L', 'ARHGAP32', 'SFN', 'GAB2', 'GAB1', 'ARRB1', 'FZR1', 'SMURF1', 'DZIP3', 'ABI2', 'ZWINT', 'HNRNPD', 'SORT1', 'SYNCRIP', 'SGTB', 'PTPRK', 'ASB3', 'BICD1', 'OBSL1', 'CUL7', 'GPHN', 'SEC61B', 'CBS', 'PRDX4', 'SEC16A', 'ADAM10', 'GRAP', 'SFI1', 'KRT19', 'CETN2', 'LPXN', 'MAD2L2', 'SERTAD1', 'CCDC57', 'CETN1', 'USP9X', 'LMNB2', 'PPP1CA', 'MIF4GD', 'HGS', 'DDX19A', 'SVIL', 'UBQLN4', 'HINFP', 'DHX16', 'ILF2', 'PDXDC1', 'LSM5', 'HDAC4', 'EXOSC6', 'PDE4DIP', 'PSMC1', 'SLBP', 'BMT2', 'SMARCB1', 'APEX1', 'CHCHD2', 'ENKD1', 'FAM110A', 'EIF3G', 'ATPAF2', 'AQP1' ...
# <class 'list'>
# ##################
# (11792,)

# %%
# for node in J.nodes(data=True):
    # print(node('name'))
# nx.get_node_attributes(J,'name')

nodes = J.nodes(data=True)
count=0
NODES_src=[]
NODES_tgt=[]
for src, tgt, attr in J.edges(data=True):
  count=count+1
  NODES_src.append(src)
  NODES_tgt.append(tgt)
  # print type(node1)
  src_attr = nodes[src]
  tgt_attr = nodes[tgt]
  ###### print(str(src) + ' - ' + str(tgt) + ' : ' + attr['name'] + ' : ' + src_attr['name'] + ' , ' + tgt_attr['name'])
  # print(src)
  # textDATA=src_attr['name'] + '\t' + tgt_attr['name']
  # print(textDATA)
print(count)
print(src)
print(type(src))
print(np.shape(src))
print(len(src))
print(np.shape(NODES_src))
print('##########')
print(tgt)
print(type(tgt))
print(np.shape(tgt))
print(len(tgt))
print(NODES_tgt)
print(type(NODES_tgt))
# Out:
# 318004
# Nsp12
# <class 'str'>
# ()
# 5
# (318004,)
# ##########
# TYSND1
# <class 'str'>
# ()
# 6
# ['POLR2D', 'POLR2B', 'POLR2C', 'POLR2E', 'POLR2F', 'POLR2G', 'POLR2H', 'POLR2I', 'POLR2L', 'RADIL', 'NFKBIA', 'DCK', 'ZC3H13', 'APP', 'FBXW7', 'POLR2K', 'ELL2', 'AFF4', 'MSX1', 'RPAP2', 'HECTD1', 'HERC2', 'NR2C2', 'DTX2', 'NEDD9', 'OSTF1', 'HLCS', 'GRB2', 'KANK2', 'SMAD1', 'SMAD2', 'UBR5', 'CHMP4B', 'BRD4', 'CHD9', 'SRSF3', 'CDC23', 'ZCCHC10', 'UBTF', 'ANAPC2', 'ZNF281', 'HCFC1', 'NOLC1', 'FBL', 'TCOF1', 'RUVBL1', 'RANGAP1', 'PPIG', 'NOL8', 'PNN', 'LMNA', 'AHCTF1', 'SMC4', 'ANAPC5', 'IPO4', 'RNPS1', 'PRPF4B', 'DDX21', 'DDB1', 'NUMA1', 'KPNA2', 'HSPD1', 'HSPA9', 'MYBBP1A', 'DNM2', 'DNAJA1', 'ZBTB9', 'LUC7L3', 'DDX20', 'CMSS1', 'NPM1', 'DDX50', 'HDAC6', 'TARDBP', 'PTBP1', 'DDX3X', 'NOP58', 'SNRPD1', 'BAG2', 'DDX52', 'U2SURP', 'HNRNPM', 'DNALI1', 'EEF1A1', 'NONO', 'GCN1', 'TMPO', 'RSL1D1', 'ACIN1', 'TTN', 'RBM39', 'DHRS7B', 'PRKCA', 'YWHAG', 'SETDB1', 'KAT5', 'LMO3', 'MED19', 'WWP2', 'MED10', 'MED9', 'MED29', 'MED28', 'MED26', 'XRCC5', 'RPAP2', 'IKBKG', 'TRIM29', 'ZSCAN1', 'INTS5', 'INTS6', 'ELAVL1', 'CUL5', 'DCTN2', 'FTL', 'ESR1', 'SRC', 'PSMB9', 'ELOA', 'GPN3', 'PIH1D1', 'RPRD1B', 'ELP2', 'MCFD2', 'ACTR1A', 'MCM3', 'PUS7', 'SNRPA1', 'CTR9', 'RNGTT', 'RPRD1A', 'LMO2', 'SYDE1', 'ASB6', 'CPNE2', 'MED1', 'MED21', 'TNIP2', 'TPT1', 'ARHGEF19', 'BRD4', 'RBBP6', 'ERCC2', 'NUDCD1', 'NEURL4', 'EPAS1', 'NMNAT1', 'MED6', 'MED30', 'SUPT6H', 'MED27', 'MED8', 'MED17', 'MED20', 'SCAF4', 'MED4', 'RPRD2', 'ATF7IP', 'NR5A2', 'HAX1', 'WWP2', 'MED7', 'MACROH2A1', 'MED26', 'POLR1A', 'SNAI1', 'MYC', 'ESR1', 'RAF1', 'TUBB', 'HMGB1', 'MAPT', 'SRC', 'ERCC2', 'LMO2', 'MED10', 'RPAP2', 'RPAP3', 'LZTR1', 'IKBKG', 'ZSCAN1', 'INTS5', 'ZC3H13', 'WDR82', 'SUB1', 'PIDD1', 'CUL3', 'CUL5', 'CCNH', 'TUBA4A', 'TUBB4B', 'DCTN1', 'MDC1', 'VCP', 'HDAC11', 'FBXO6', 'HECW2', 'ITCH', 'NEDD4', 'WWOX', 'RABEP2', 'ILK', 'XRN2', 'ELOA', 'SUZ12', 'RPRD1B', 'GPN2', 'EEF1A1', 'EEFSEC', 'IFI16', 'MED4', 'DNAJC7', 'CTR9', 'GPN3', 'PIH1D1', 'ASB6', 'CPNE2', 'AAR2', 'INO80B', 'TRIM25', 'G3BP1', 'HIF1AN', 'EGLN3', 'RMND5A', 'RIPK4', 'MAPK6', 'HIF1A', 'ZMYND8', 'TNIP2', 'CDC34', 'ZUP1', 'ESR2', 'GRWD1', 'VIRMA', 'PHB', 'RBX1', 'NR2C2', 'SCAI', 'DCTN4', 'BICD1', 'OTUD5', 'MAP3K14', 'BCL2L14', 'IRF7', 'UNC93B1', 'ITFG1', 'FUS', 'BIRC3', 'LMBR1L', 'TRIM28', 'PTEN', 'PAK1', 'SNIP1', 'NCBP2', 'SYDE2', 'RMC1', 'CIC', 'RBM39', 'NKX3-1', 'MAGI2', 'PPP5C', 'NBEAL2', 'NEURL4', 'LRRK2', 'MED31', 'RPRD1A', 'BTF3', 'ATP6V1B2', 'PSMB9', 'OBSL1', 'POLR3A', 'BRD2', 'RNGTT', 'RECQL4', 'STAU1', 'BRD1', 'BRD4', 'TET3', 'WWP2', 'PRMT5', 'XPO1', 'HTRA2', 'MED7', 'AKAP10', 'NUDT21', 'TADA2A', 'FN1', 'ESR1', 'JUN', 'UBC', 'SRC', 'UBE2W', 'ERG28', 'EEF1A1', 'SMARCC2', 'LRIF1', 'POLR2C', 'TAF15', 'CCHCR1', 'RPAP2', 'INTS5', 'INTS6', 'INTS3', 'PHF8', 'ZNF326', 'CUL3', 'CUL5', 'COPS5', 'MDC1', 'WDR77', 'SUPT6H', 'EIF3E', 'ERCC3', 'INTS10', 'MED17', 'NELFB', 'INTS12', 'MED27', 'SOX2', 'DNMT3B', 'DNMT3A', 'NFKBIA', 'NEDD4', 'EHBP1L1', 'MAP4', 'PPP4R1', 'WWOX', 'PSMB9', 'ELOA', 'GPN3', 'PIH1D1', 'RPRD1B', 'RPS9', 'CNTRL', 'KLC1', 'LEO1', 'LMO2', 'EGLN3', 'MAPK6', 'TNIP2', 'ESR2', 'DPF2', 'PPP1CC', 'OTUD5', 'BAZ1B', 'IMMP1L', 'IMMP2L', 'HSCB', 'CHMP4C', 'TRIM33', 'NMRAL1', 'INTS1', 'INTS2', 'RIF1', 'NUDCD1', 'NEURL4', 'EPAS1', 'MED30', 'MED31', 'RPRD1A', 'STC2', 'SMAP', 'DHX15', 'RNGTT', 'DLD', 'RECQL4', 'BRD1', 'BRD4', 'TET3', 'WWP2', 'DNM1L', 'POLR1G', 'MED7', 'SCAF4', 'ARIH2', 'SOD1', 'FOS', 'ESR1', 'CD74', 'JUN', 'NPM1', 'HSP90AA1', 'MAPT', 'SRC', 'HSP90B1', 'RPA2', 'ERCC2', 'MED9', 'MED29', 'TAF15', 'USP11', 'TAF10', 'LZTR1', 'IKBKG', 'TRIM29', 'ZSCAN1', 'INTS3', 'INTS5', 'INTS6', 'MED28', 'FKBP14', 'INTS10', 'ARRB1', 'ARRB2', 'CUL3', 'COPS5', 'MDC1', 'SMG1', 'SRPK1', 'NEDD4', 'PAAF1', 'SEC13', 'RABEP2', 'RPA3', 'RPA1', 'WWOX', 'PSMB9', 'ELOA', 'CUL7', 'CCDC8', 'PIH1D1', 'RPRD1B', 'EEF1A1', 'RPS5', 'UXT', 'PPP1CC', 'ZNF589', 'HELB', 'RPAP2', 'GPN3', 'LMO2', 'CSNK2A2', 'SPINDOC', 'BRMS1', 'CSNK2B', 'CSNK2A1', 'SUPT6H', 'PPP1R7', 'PPP1CB', 'HSD17B10', 'EGLN3', 'UBE2M', 'PRPF8', 'ESR2', 'DPF2', 'REST', 'MAD2L2', ...
# <class 'list'>

# %%
print(src_attr)
# Out:
# {}

# %%
noOfNodes=count
# for node in J.nodes(data=True):
    # print(node('name'))
# nx.get_node_attributes(J,'name')
EDGE_INDEXING=np.zeros((count,2))
EDGE_INDEXING=EDGE_INDEXING.astype(int)
nodes = J.nodes(data=True)
count=0
for src, tgt, attr in J.edges(data=True):
  
  # print type(node1)
  src_attr = nodes[src]
  tgt_attr = nodes[tgt]
  
  
  EDGE_INDEXING[count,0]=nodes_J_.index(src)
  EDGE_INDEXING[count,1]=nodes_J_.index(tgt)
  
  
  
  # print(src + ' - ' + tgt)
  # print(src_attr['name'] + ' , ' + tgt_attr['name'])
  # textDATA=src_attr['name'] + '\t' + tgt_attr['name']
  # print(textDATA)
  count=count+1
# print(count)

# %%
print(EDGE_INDEXING)
# Out:
# [[    0     1]
#  [    0     2]
#  [    0     3]
#  ...
#  [11785 11786]
#  [11789 11790]
#  [11789 11791]]

# %%
print(type(EDGE_INDEXING))
# Out:
# <class 'numpy.ndarray'>

# %%
print(np.shape(EDGE_INDEXING))
# Out:
# (318004, 2)

# %%
# ! pip install pcst_fast
# Out:
# Collecting pcst_fast
#   Downloading pcst_fast-1.0.7-cp37-cp37m-manylinux1_x86_64.whl (730 kB)
#      |████████████████████████████████| 730 kB 7.4 MB/s
# Collecting pybind11>=2.1.0
#   Downloading pybind11-2.9.0-py2.py3-none-any.whl (210 kB)
#      |████████████████████████████████| 210 kB 53.1 MB/s
# Installing collected packages: pybind11, pcst-fast
# Successfully installed pcst-fast-1.0.7 pybind11-2.9.0

# %%
Shape=np.shape(EDGE_INDEXING)
print(Shape)
print(type(Shape))
# Out:
# (318004, 2)
# <class 'tuple'>

# %%
noOfEdges=Shape[0]

import random

costs=np.zeros((noOfEdges))


for i in range (noOfEdges):
  costs[i]=random.uniform(0, 1)

# %%
prizes=np.zeros((noOfNodes))


for i in range (noOfNodes):
  prizes[i]=random.uniform(0, 1)

# %%
print(np.shape(prizes))
# Out:
# (318004,)

# %%
edges=EDGE_INDEXING

import pcst_fast
op_vertices, op_edges = pcst_fast.pcst_fast(edges, prizes, costs, -1, 1, 'strong', 0)

# %%
print(edges)
# Out:
# [[    0     1]
#  [    0     2]
#  [    0     3]
#  ...
#  [11785 11786]
#  [11789 11790]
#  [11789 11791]]

# %%
print(np.unique(prizes))
# Out:
# [9.61569029e-07 8.39801077e-06 1.25284561e-05 ... 9.99994026e-01
#  9.99996093e-01 9.99996302e-01]

# %%
print(costs)
# Out:
# [0.7768542  0.62874379 0.78834493 ... 0.421088   0.63520794 0.0280731 ]

# %%
print(op_vertices)
# Out:
# [    0     1     2 ... 11787 11789 11791]

# %%
print(op_edges)
# Out:
# [112406 189017 137208 ... 137776 134484 287537]

# %%
###################################################################################################

# %%
print(type(src))
# Out:
# <class 'str'>

# %%
#################################################################################################
