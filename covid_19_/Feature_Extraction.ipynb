# %% [markdown]
# # Feature_Extraction

# %% [markdown]
# change image folder path to the RGB images that are generated earlier
#
# change output location for .csv file
#
# .csv file will have 2 columns 1st with image path and 2nd with extracted features from that image.

# %%
import os
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.models import Model
import csv
import glob

# %%
# load Model
model = VGG16()

# %%
model = Model(inputs=model.inputs, outputs=model.layers[-2].output)
features = {}

image_folder = "D:/PROJECT_BIOMEDICAL/6_to_3_Image/output/"
#image_folder = "C:/Users/Gaurav/Desktop/output/"


# Get a list of image files in the folder
image_files = glob.glob(image_folder + "*.png")

t = 0

for image_path in image_files:

        # Print the path that we are working on (just to keep track of the process)
        print(image_path)

        # Load the image
        img = load_img(image_path, target_size=(224, 224))

        # Convert pixels to numpy
        img = img_to_array(img)

        # Reshape the image for the model
        img = img.reshape((1, img.shape[0], img.shape[1], img.shape[2]))

        # Preprocess the image
        img = preprocess_input(img)

        # Extract features
        feature = model.predict(img, verbose=0)

        # Store features
        features[image_path] = feature
        
        t += 1
        print(t)
        
        
# Write features to CSV file
csv_file_path = 'D:/PROJECT_BIOMEDICAL/Data_Set/rxrx1/Features/features.csv'
fieldnames = ['image_path', 'feature']

with open(csv_file_path, mode='w', newline='') as csv_file:
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
    writer.writeheader()
    for image_path, feature in features.items():
        writer.writerow({'image_path': image_path, 'feature': feature})
# Out:
# D:/PROJECT_BIOMEDICAL/6_to_3_Image/output\HUVEC-19_plate_3_wall_N14_site_2.png
# 1
# D:/PROJECT_BIOMEDICAL/6_to_3_Image/output\HUVEC-19_plate_3_wall_N15_site_1.png
# 2
# D:/PROJECT_BIOMEDICAL/6_to_3_Image/output\HUVEC-19_plate_3_wall_N15_site_2.png
# 3
# D:/PROJECT_BIOMEDICAL/6_to_3_Image/output\HUVEC-19_plate_3_wall_N16_site_1.png
# 4
# D:/PROJECT_BIOMEDICAL/6_to_3_Image/output\HUVEC-19_plate_3_wall_N16_site_2.png
# 5
# D:/PROJECT_BIOMEDICAL/6_to_3_Image/output\HUVEC-19_plate_3_wall_N17_site_1.png
# 6
# D:/PROJECT_BIOMEDICAL/6_to_3_Image/output\HUVEC-19_plate_3_wall_N17_site_2.png
# 7
# D:/PROJECT_BIOMEDICAL/6_to_3_Image/output\HUVEC-19_plate_3_wall_N18_site_1.png
# 8
# D:/PROJECT_BIOMEDICAL/6_to_3_Image/output\HUVEC-19_plate_3_wall_N18_site_2.png
# 9
# D:/PROJECT_BIOMEDICAL/6_to_3_Image/output\HUVEC-19_plate_3_wall_N19_site_1.png
# 10
# D:/PROJECT_BIOMEDICAL/6_to_3_Image/output\HUVEC-19_plate_3_wall_N19_site_2.png
# 11
# ...

# %%
# Write features to CSV file
csv_file_path = 'D:/PROJECT_BIOMEDICAL/Data_Set/rxrx1/Features/features.csv'
fieldnames = ['image_path', 'feature']

with open(csv_file_path, mode='w', newline='') as csv_file:
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
    writer.writeheader()
    for image_path, feature in features.items():
        writer.writerow({'image_path': image_path, 'feature': feature})
